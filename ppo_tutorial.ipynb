# %% [markdown]
# # Proximal Policy Optimization (PPO) Tutorial

# %% [markdown]
# ## 1. Environment Preparation

# %% [markdown]
# ### 1.1 Download Packages for BipedalWalker-v3

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# !pip install box2d-py
# !pip install 'gym[Box2D]'
# Out:
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (2.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.41.1)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay->colabgymrender==1.0.2) (0.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)
# Requirement already satisfied: gym[Box2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.5.0)
# Requirement already satisfied: box2d-py~=2.3.5; extra == "box2d" in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (2.3.8)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box2D]) (0.16.0)

# %% [markdown]
# ### 1.2 Mount Drive and Set Project Path

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
project_root = '/content/drive/My Drive/ppo_tutorial/'
sys.path.append(project_root)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.3 Test the BipedalWalker-v3 Environment

# %%
import os
import gym
import torch
import torch.nn as nn
import numpy as np
from colabgymrender.recorder import Recorder

env = gym.make('BipedalWalker-v3')
s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
print(s_dim)
print(a_dim)
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# 24
# 4

# %% [markdown]
# ## 2. Policy Network & Value Network Construction

# %% [markdown]
# ### 2.1 Diagonal Gaussian Distribution Module

# %%
#AddBias module
class AddBias(nn.Module):
    def __init__(self, bias):
        super(AddBias, self).__init__()
        self._bias = nn.Parameter(bias.unsqueeze(1))
    
    def forward(self, x):
        bias = self._bias.t().view(1, -1)
        return x + bias

#Gaussian distribution with given mean & std.
class FixedNormal(torch.distributions.Normal):
    def log_probs(self, x):
        return super().log_prob(x).sum(-1)
    
    def entropy(self):
        return super().entropy().sum(-1)

    def mode(self):
        return self.mean

#Diagonal Gaussian module
class DiagGaussian(nn.Module):
    def __init__(self, inp_dim, out_dim):
        super(DiagGaussian, self).__init__()
        self.fc_mean = nn.Linear(inp_dim, out_dim)
        self.b_logstd = AddBias(torch.zeros(out_dim))
    
    def forward(self, x):
        mean = self.fc_mean(x)
        logstd = self.b_logstd(torch.zeros_like(mean))
        return FixedNormal(mean, logstd.exp())

# %% [markdown]
# ### 2.2 Policy Network & Value Network Module

# %%
#Policy Network
class PolicyNet(nn.Module):
    #Constructor
    def __init__(self, s_dim, a_dim):
        super(PolicyNet, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )
        self.dist = DiagGaussian(128, a_dim)
    
    #Forward pass
    def forward(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            action = dist.mode()
        else:
            action = dist.sample()
        
        return action, dist.log_probs(action)
    
    #Choose an action (stochastically or deterministically)
    def choose_action(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            return dist.mode()

        return dist.sample()
    
    #Evaluate a state-action pair (output log-prob. & entropy)
    def evaluate(self, state, action):
        feature = self.main(state)
        dist = self.dist(feature)
        return dist.log_probs(action), dist.entropy()

#Value Network
class ValueNet(nn.Module):
    #Constructor
    def __init__(self, s_dim):
        super(ValueNet, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    
    #Forward pass
    def forward(self, state):
        return self.main(state)[:, 0]

# %% [markdown]
# ### 2.3 Create Policy Network & Value Network

# %%
policy_net = PolicyNet(s_dim, a_dim)
value_net = ValueNet(s_dim)
print(policy_net)
print(value_net)
# Out:
# PolicyNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#   )
#   (dist): DiagGaussian(
#     (fc_mean): Linear(in_features=128, out_features=4, bias=True)
#     (b_logstd): AddBias()
#   )
# )
# ValueNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## 3. Environment Runner Construction

# %% [markdown]
# ### 3.1 EnvRunner Class

# %%
class EnvRunner:
    #Constructor
    def __init__(self, s_dim, a_dim, gamma=0.99, lamb=0.95, max_step=2048, device='cpu'):
        self.s_dim = s_dim
        self.a_dim = a_dim
        self.gamma = gamma
        self.lamb = lamb
        self.max_step = max_step
        self.device = device

        #Storages (state, action, value, reward, a_logp)
        self.mb_states = np.zeros((self.max_step, self.s_dim), dtype=np.float32)
        self.mb_actions = np.zeros((self.max_step, self.a_dim), dtype=np.float32)
        self.mb_values = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_rewards = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_a_logps = np.zeros((self.max_step,), dtype=np.float32)
    
    #Compute discounted return
    def compute_discounted_return(self, rewards, last_value, gamma=0.99):
        returns = np.zeros_like(rewards)
        n_step = len(rewards)

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                returns[t] = rewards[t] + gamma * last_value
            else:
                returns[t] = rewards[t] + gamma * returns[t+1]

        return returns
    
    #Compute generalized advantage estimation
    def compute_gae(self, rewards, values, last_value, gamma=0.99, lamb=0.95):
        advs = np.zeros_like(rewards)
        n_step = len(rewards)
        last_gae_lam = 0.0

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                next_value = last_value
            else:
                next_value = values[t+1]

            delta = rewards[t] + gamma*next_value - values[t]
            advs[t] = last_gae_lam = delta + gamma*lamb*last_gae_lam

        return advs + values

    #Run an episode using the policy net & value net
    def run(self, env, policy_net, value_net):
        #Run an episode
        state = env.reset()   #Initial state
        episode_len = self.max_step

        for step in range(self.max_step):
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
            action, a_logp = policy_net(state_tensor)
            value = value_net(state_tensor)

            action = action.cpu().numpy()[0]
            a_logp = a_logp.cpu().numpy()
            value  = value.cpu().numpy()

            self.mb_states[step] = state
            self.mb_actions[step] = action
            self.mb_a_logps[step] = a_logp
            self.mb_values[step] = value

            state, reward, done, info = env.step(action)
            self.mb_rewards[step] = reward

            if done:
                episode_len = step + 1
                break
        
        #Compute returns
        last_value = value_net(
            torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
        ).cpu().numpy()

        mb_returns = self.compute_discounted_return(
            self.mb_rewards[:episode_len],
            last_value,
            self.lamb
        )
        '''
        mb_returns = self.compute_gae(
            self.mb_rewards[:episode_len],
            self.mb_values[:episode_len],
            last_value,
            self.gamma,
            self.lamb
        )
        '''

        return self.mb_states[:episode_len], \
                self.mb_actions[:episode_len], \
                self.mb_a_logps[:episode_len], \
                self.mb_values[:episode_len], \
                mb_returns, \
                self.mb_rewards[:episode_len]

# %% [markdown]
# ### 3.2 Create EnvRunner

# %%
runner = EnvRunner(s_dim, a_dim)

# %% [markdown]
# ## 4. PPO Algorithm

# %% [markdown]
# ### 4.1 PPO Class

# %%
class PPO:
    #Constructor
    def __init__(self, policy_net, value_net, lr=1e-4, max_grad_norm=0.5, ent_weight=0.01, clip_val=0.2, sample_n_epoch=4, sample_mb_size=64, device='cpu'):
        self.policy_net = policy_net
        self.value_net = value_net
        self.max_grad_norm = max_grad_norm
        self.ent_weight = ent_weight
        self.clip_val = clip_val
        self.sample_n_epoch = sample_n_epoch
        self.sample_mb_size = sample_mb_size
        self.device = device
        self.opt_polcy = torch.optim.Adam(policy_net.parameters(), lr)
        self.opt_value = torch.optim.Adam(value_net.parameters(), lr)
    
    #Train the policy net & value net using PPO
    def train(self, mb_states, mb_actions, mb_old_values, mb_advs, mb_returns, mb_old_a_logps):
        #Convert numpy array to tensor
        mb_states = torch.from_numpy(mb_states).to(self.device)
        mb_actions = torch.from_numpy(mb_actions).to(self.device)
        mb_old_values = torch.from_numpy(mb_old_values).to(self.device)
        mb_advs = torch.from_numpy(mb_advs).to(self.device)
        mb_returns = torch.from_numpy(mb_returns).to(self.device)
        mb_old_a_logps = torch.from_numpy(mb_old_a_logps).to(self.device)
        episode_length = len(mb_states)
        rand_idx = np.arange(episode_length)
        sample_n_mb = episode_length // self.sample_mb_size

        if sample_n_mb <= 0:
            sample_mb_size = episode_length
            sample_n_mb = 1
        else:
            sample_mb_size = self.sample_mb_size

        for i in range(self.sample_n_epoch):
            np.random.shuffle(rand_idx)

            for j in range(sample_n_mb):
                #Randomly sample a batch for training
                sample_idx = rand_idx[j*sample_mb_size : (j+1)*sample_mb_size]
                sample_states = mb_states[sample_idx]
                sample_actions = mb_actions[sample_idx]
                sample_old_values = mb_old_values[sample_idx]
                sample_advs = mb_advs[sample_idx]
                sample_returns = mb_returns[sample_idx]
                sample_old_a_logps = mb_old_a_logps[sample_idx]

                sample_a_logps, sample_ents = self.policy_net.evaluate(sample_states, sample_actions)
                sample_values = self.value_net(sample_states)
                ent = sample_ents.mean()

                #Compute value loss
                v_pred_clip = sample_old_values + torch.clamp(sample_values - sample_old_values, -self.clip_val, self.clip_val)
                v_loss1 = (sample_returns - sample_values).pow(2)
                v_loss2 = (sample_returns - v_pred_clip).pow(2)
                v_loss = torch.max(v_loss1, v_loss2).mean()

                #Compute policy gradient loss
                ratio = (sample_a_logps - sample_old_a_logps).exp()
                pg_loss1 = -sample_advs * ratio
                pg_loss2 = -sample_advs * torch.clamp(ratio, 1.0-self.clip_val, 1.0+self.clip_val)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean() - self.ent_weight*ent

                #Train actor
                self.opt_polcy.zero_grad()
                pg_loss.backward()
                nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.max_grad_norm)
                self.opt_polcy.step()

                #Train critic
                self.opt_value.zero_grad()
                v_loss.backward()
                nn.utils.clip_grad_norm_(self.value_net.parameters(), self.max_grad_norm)
                self.opt_value.step()

        return pg_loss.item(), v_loss.item(), ent.item()

# %% [markdown]
# ### 4.2 Create PPO Agent

# %%
agent = PPO(policy_net, value_net)

# %% [markdown]
# ## 5. Training and Testing Process

# %% [markdown]
# ### 5.1 Play an Episode for Evaluation

# %%
def play(policy_net):
    render_env = Recorder(gym.make('BipedalWalker-v3'), project_root + '/video')

    with torch.no_grad():
        state = render_env.reset()
        total_reward = 0
        length = 0

        while True:
            #render_env.render()
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device='cpu')
            action = policy_net.choose_action(state_tensor, deterministic=True).cpu().numpy()
            state, reward, done, info = render_env.step(action[0])
            total_reward += reward
            length += 1

            if done:
                print("[Evaluation] Total reward = {:.6f}, length = {:d}".format(total_reward, length), flush=True)
                break
    render_env.play()
    render_env.close()

# %%
play(policy_net)
# Out:
# [Evaluation] Total reward = -111.058200, length = 73
# 100%|██████████| 75/75 [00:00<00:00, 259.79it/s]

# %% [markdown]
# ### 5.2 Train the Networks using PPO

# %%
def train(env, runner, policy_net, value_net, agent, max_episode=5000):
    mean_total_reward = 0
    mean_length = 0
    save_dir = project_root + '/save'

    if not os.path.exists(save_dir):
        os.mkdir(save_dir)

    for i in range(max_episode):
        #Run an episode to collect data
        with torch.no_grad():
            mb_states, mb_actions, mb_old_a_logps, mb_values, mb_returns, mb_rewards = runner.run(env, policy_net, value_net)
            mb_advs = mb_returns - mb_values
            mb_advs = (mb_advs - mb_advs.mean()) / (mb_advs.std() + 1e-6)
        
        #Train the model using the collected data
        pg_loss, v_loss, ent = agent.train(mb_states, mb_actions, mb_values, mb_advs, mb_returns, mb_old_a_logps)
        mean_total_reward += mb_rewards.sum()
        mean_length += len(mb_states)
        print("[Episode {:4d}] total reward = {:.6f}, length = {:d}".format(i, mb_rewards.sum(), len(mb_states)))

        #Show the current result & save the model
        if i % 200 == 0:
            print("\n[{:5d} / {:5d}]".format(i, max_episode))
            print("----------------------------------")
            print("actor loss = {:.6f}".format(pg_loss))
            print("critic loss = {:.6f}".format(v_loss))
            print("entropy = {:.6f}".format(ent))
            print("mean return = {:.6f}".format(mean_total_reward / 100))
            print("mean length = {:.2f}".format(mean_length / 100))
            print("\nSaving the model ... ", end="")
            torch.save({
                "it": i,
                "PolicyNet": policy_net.state_dict(),
                "ValueNet": value_net.state_dict()
            }, os.path.join(save_dir, "model.pt"))
            print("Done.")
            print()
            play(policy_net)
            mean_total_reward = 0
            mean_length = 0

# %%
train(env, runner, policy_net, value_net, agent)
env.close()
# Out:
# [Episode    0] total reward = -101.405266, length = 1600
#
# [    0 /  5000]
# ----------------------------------
# actor loss = 0.056528
# critic loss = 1.490289
# entropy = 5.671003
# mean return = -1.014053
# mean length = 16.00
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -111.704622, length = 80
#  99%|█████████▉| 81/82 [00:00<00:00, 262.01it/s]
# [Episode    1] total reward = -114.313126, length = 1600
# [Episode    2] total reward = -109.681152, length = 55
# [Episode    3] total reward = -95.253601, length = 1600
# [Episode    4] total reward = -120.235931, length = 102
# [Episode    5] total reward = -115.665123, length = 106
# [Episode    6] total reward = -110.038933, length = 100
# [Episode    7] total reward = -113.464943, length = 174
# [Episode    8] total reward = -110.747955, length = 57
# [Episode    9] total reward = -114.234375, length = 76
# [Episode   10] total reward = -109.079987, length = 48
# [Episode   11] total reward = -108.891266, length = 43
# [Episode   12] total reward = -103.560921, length = 78
# [Episode   13] total reward = -111.903427, length = 71
# [Episode   14] total reward = -101.470703, length = 1600
# [Episode   15] total reward = -113.386108, length = 94
# [Episode   16] total reward = -117.731384, length = 76
# [Episode   17] total reward = -100.212234, length = 1600
# [Episode   18] total reward = -113.922935, length = 65
# [Episode   19] total reward = -111.807327, length = 73
# [Episode   20] total reward = -122.308998, length = 80
# [Episode   21] total reward = -107.268929, length = 53
# [Episode   22] total reward = -112.768654, length = 63
# [Episode   23] total reward = -90.239822, length = 1600
# [Episode   24] total reward = -114.593384, length = 89
# [Episode   25] total reward = -82.974945, length = 1600
# [Episode   26] total reward = -112.794617, length = 156
# [Episode   27] total reward = -110.536873, length = 53
# [Episode   28] total reward = -127.685661, length = 112
# [Episode   29] total reward = -105.763718, length = 98
# [Episode   30] total reward = -114.023598, length = 130
# [Episode   31] total reward = -99.190765, length = 1600
# [Episode   32] total reward = -117.816101, length = 57
# [Episode   33] total reward = -113.618324, length = 87
# [Episode   34] total reward = -111.995995, length = 78
# [Episode   35] total reward = -113.585922, length = 81
# [Episode   36] total reward = -119.825912, length = 98
# [Episode   37] total reward = -122.165085, length = 88
# [Episode   38] total reward = -88.145737, length = 1600
# [Episode   39] total reward = -113.435699, length = 69
# [Episode   40] total reward = -80.050041, length = 1600
# [Episode   41] total reward = -116.010506, length = 136
# [Episode   42] total reward = -118.547607, length = 161
# [Episode   43] total reward = -110.954124, length = 62
# [Episode   44] total reward = -114.183365, length = 83
# [Episode   45] total reward = -111.460411, length = 72
# [Episode   46] total reward = -112.562920, length = 70
# [Episode   47] total reward = -78.436279, length = 1600
# [Episode   48] total reward = -81.859451, length = 1600
# [Episode   49] total reward = -119.453445, length = 108
# [Episode   50] total reward = -108.762268, length = 115
# [Episode   51] total reward = -116.244133, length = 56
# [Episode   52] total reward = -113.276443, length = 81
# [Episode   53] total reward = -83.803329, length = 1600
# [Episode   54] total reward = -112.753044, length = 100
# [Episode   55] total reward = -123.959419, length = 189
# [Episode   56] total reward = -86.997536, length = 1600
# [Episode   57] total reward = -117.469017, length = 69
# [Episode   58] total reward = -78.095299, length = 1600
# [Episode   59] total reward = -116.684372, length = 52
# [Episode   60] total reward = -114.148598, length = 147
# [Episode   61] total reward = -116.647079, length = 51
# [Episode   62] total reward = -109.912178, length = 118
# [Episode   63] total reward = -114.641884, length = 64
# [Episode   64] total reward = -121.075546, length = 147
# [Episode   65] total reward = -113.989876, length = 73
# [Episode   66] total reward = -121.852631, length = 126
# [Episode   67] total reward = -111.272842, length = 51
# [Episode   68] total reward = -112.601128, length = 77
# [Episode   69] total reward = -118.300026, length = 139
# [Episode   70] total reward = -114.207542, length = 87
# [Episode   71] total reward = -116.604179, length = 85
# [Episode   72] total reward = -114.735046, length = 131
# [Episode   73] total reward = -120.146286, length = 85
# [Episode   74] total reward = -114.564102, length = 52
# [Episode   75] total reward = -109.723854, length = 54
# [Episode   76] total reward = -110.414307, length = 52
# [Episode   77] total reward = -125.156708, length = 201
# [Episode   78] total reward = -122.538162, length = 169
# [Episode   79] total reward = -119.483887, length = 88
# [Episode   80] total reward = -119.723557, length = 90
# [Episode   81] total reward = -117.173752, length = 92
# [Episode   82] total reward = -119.314980, length = 166
# [Episode   83] total reward = -125.413773, length = 133
# [Episode   84] total reward = -123.928940, length = 118
# [Episode   85] total reward = -113.329567, length = 146
# [Episode   86] total reward = -114.216080, length = 64
# [Episode   87] total reward = -113.997704, length = 100
# [Episode   88] total reward = -116.100868, length = 96
# [Episode   89] total reward = -115.752686, length = 198
# [Episode   90] total reward = -114.895851, length = 63
# [Episode   91] total reward = -112.565117, length = 60
# [Episode   92] total reward = -117.031281, length = 76
# [Episode   93] total reward = -113.286575, length = 58
# [Episode   94] total reward = -118.706589, length = 57
# [Episode   95] total reward = -113.689873, length = 170
# [Episode   96] total reward = -118.054031, length = 87
# [Episode   97] total reward = -115.722412, length = 144
# [Episode   98] total reward = -120.356049, length = 119
# [Episode   99] total reward = -116.859093, length = 91
# [Episode  100] total reward = -108.494736, length = 44
# [Episode  101] total reward = -114.235199, length = 55
# [Episode  102] total reward = -120.296860, length = 68
# [Episode  103] total reward = -115.581917, length = 69
# [Episode  104] total reward = -112.392174, length = 125
# [Episode  105] total reward = -117.581421, length = 99
# [Episode  106] total reward = -114.043610, length = 113
# [Episode  107] total reward = -116.316734, length = 48
# [Episode  108] total reward = -124.520691, length = 140
# [Episode  109] total reward = -116.052963, length = 57
# [Episode  110] total reward = -117.417519, length = 143
# [Episode  111] total reward = -115.151268, length = 130
# [Episode  112] total reward = -111.339851, length = 78
# [Episode  113] total reward = -114.922638, length = 82
# [Episode  114] total reward = -113.606613, length = 89
# [Episode  115] total reward = -112.130371, length = 63
# [Episode  116] total reward = -122.021744, length = 141
# [Episode  117] total reward = -118.417793, length = 133
# [Episode  118] total reward = -114.351051, length = 98
# [Episode  119] total reward = -114.507690, length = 87
# [Episode  120] total reward = -115.169022, length = 63
# [Episode  121] total reward = -108.160164, length = 50
# [Episode  122] total reward = -118.218903, length = 127
# [Episode  123] total reward = -113.740135, length = 73
# [Episode  124] total reward = -114.212723, length = 78
# [Episode  125] total reward = -113.235275, length = 67
# [Episode  126] total reward = -116.458115, length = 95
# [Episode  127] total reward = -113.052742, length = 104
# [Episode  128] total reward = -116.855560, length = 98
# [Episode  129] total reward = -113.947327, length = 131
# [Episode  130] total reward = -121.369614, length = 103
# [Episode  131] total reward = -119.109428, length = 98
# [Episode  132] total reward = -118.974304, length = 85
# [Episode  133] total reward = -112.595612, length = 65
# [Episode  134] total reward = -116.606865, length = 98
# [Episode  135] total reward = -116.967224, length = 119
# [Episode  136] total reward = -115.016548, length = 64
# [Episode  137] total reward = -113.313293, length = 129
# [Episode  138] total reward = -117.523727, length = 156
# [Episode  139] total reward = -113.291969, length = 65
# [Episode  140] total reward = -112.976631, length = 75
# [Episode  141] total reward = -118.476532, length = 101
# [Episode  142] total reward = -117.124344, length = 108
# [Episode  143] total reward = -112.866508, length = 62
# [Episode  144] total reward = -112.294228, length = 81
# [Episode  145] total reward = -112.778717, length = 114
# [Episode  146] total reward = -119.238770, length = 114
# [Episode  147] total reward = -118.528244, length = 104
# [Episode  148] total reward = -111.564163, length = 66
# [Episode  149] total reward = -116.109406, length = 74
# [Episode  150] total reward = -117.059227, length = 117
# [Episode  151] total reward = -116.359512, length = 69
# [Episode  152] total reward = -111.260406, length = 158
# [Episode  153] total reward = -109.282761, length = 92
# [Episode  154] total reward = -116.889938, length = 201
# [Episode  155] total reward = -119.516792, length = 109
# [Episode  156] total reward = -124.332008, length = 120
# [Episode  157] total reward = -117.406754, length = 91
# [Episode  158] total reward = -117.395767, length = 99
# [Episode  159] total reward = -112.428864, length = 131
# [Episode  160] total reward = -116.683571, length = 123
# [Episode  161] total reward = -114.090057, length = 105
# [Episode  162] total reward = -113.444153, length = 90
# [Episode  163] total reward = -119.440231, length = 85
# [Episode  164] total reward = -116.394508, length = 107
# [Episode  165] total reward = -116.728699, length = 47
# [Episode  166] total reward = -115.524139, length = 97
# [Episode  167] total reward = -116.521324, length = 129
# [Episode  168] total reward = -110.202538, length = 53
# [Episode  169] total reward = -117.613052, length = 58
# [Episode  170] total reward = -114.119644, length = 56
# [Episode  171] total reward = -151.324142, length = 769
# [Episode  172] total reward = -115.407272, length = 97
# [Episode  173] total reward = -117.360588, length = 67
# [Episode  174] total reward = -117.613625, length = 224
# [Episode  175] total reward = -114.222626, length = 97
# [Episode  176] total reward = -116.478889, length = 141
# [Episode  177] total reward = -116.234787, length = 93
# [Episode  178] total reward = -118.501480, length = 183
# [Episode  179] total reward = -113.325714, length = 78
# [Episode  180] total reward = -112.609840, length = 165
# [Episode  181] total reward = -112.355095, length = 67
# [Episode  182] total reward = -120.755745, length = 142
# [Episode  183] total reward = -113.719063, length = 82
# [Episode  184] total reward = -113.265602, length = 67
# [Episode  185] total reward = -112.704536, length = 64
# [Episode  186] total reward = -118.455933, length = 103
# [Episode  187] total reward = -121.044533, length = 92
# [Episode  188] total reward = -115.567657, length = 94
# [Episode  189] total reward = -108.459038, length = 64
# [Episode  190] total reward = -115.264732, length = 96
# [Episode  191] total reward = -120.865494, length = 176
# [Episode  192] total reward = -112.627731, length = 65
# [Episode  193] total reward = -76.084869, length = 1600
# [Episode  194] total reward = -112.212616, length = 105
# [Episode  195] total reward = -83.500008, length = 1600
# [Episode  196] total reward = -115.751480, length = 100
# [Episode  197] total reward = -111.544167, length = 157
# [Episode  198] total reward = -116.792877, length = 126
# [Episode  199] total reward = -115.779129, length = 70
# [Episode  200] total reward = -109.571678, length = 72
#
# [  200 /  5000]
# ----------------------------------
# actor loss = -0.035199
# critic loss = 1091.028076
# entropy = 5.604138
# mean return = -226.852916
# mean length = 441.11
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -108.434890, length = 68
#  99%|█████████▊| 69/70 [00:00<00:00, 250.29it/s]
# [Episode  201] total reward = -114.780693, length = 45
# [Episode  202] total reward = -74.661919, length = 1600
# [Episode  203] total reward = -116.780289, length = 106
# [Episode  204] total reward = -115.490883, length = 123
# [Episode  205] total reward = -107.334503, length = 44
# [Episode  206] total reward = -115.129921, length = 69
# [Episode  207] total reward = -108.348572, length = 88
# [Episode  208] total reward = -116.296417, length = 92
# [Episode  209] total reward = -113.881073, length = 108
# [Episode  210] total reward = -113.793602, length = 125
# [Episode  211] total reward = -122.296768, length = 180
# [Episode  212] total reward = -116.237579, length = 74
# [Episode  213] total reward = -114.821907, length = 91
# [Episode  214] total reward = -113.709229, length = 170
# [Episode  215] total reward = -118.929878, length = 118
# [Episode  216] total reward = -115.741150, length = 164
# [Episode  217] total reward = -114.143173, length = 79
# [Episode  218] total reward = -116.044754, length = 74
# [Episode  219] total reward = -113.385948, length = 114
# [Episode  220] total reward = -112.796997, length = 82
# [Episode  221] total reward = -114.056618, length = 76
# [Episode  222] total reward = -111.915199, length = 65
# [Episode  223] total reward = -115.877609, length = 78
# [Episode  224] total reward = -115.802467, length = 95
# [Episode  225] total reward = -117.196480, length = 188
# [Episode  226] total reward = -117.976318, length = 82
# [Episode  227] total reward = -110.684616, length = 63
# [Episode  228] total reward = -111.028610, length = 54
# [Episode  229] total reward = -116.057495, length = 147
# [Episode  230] total reward = -120.447716, length = 118
# [Episode  231] total reward = -113.729568, length = 93
# [Episode  232] total reward = -112.621582, length = 101
# [Episode  233] total reward = -113.817322, length = 90
# [Episode  234] total reward = -118.805244, length = 71
# [Episode  235] total reward = -114.641487, length = 43
# [Episode  236] total reward = -116.978554, length = 151
# [Episode  237] total reward = -115.364754, length = 97
# [Episode  238] total reward = -108.676453, length = 75
# [Episode  239] total reward = -118.317001, length = 81
# [Episode  240] total reward = -119.728844, length = 61
# [Episode  241] total reward = -119.080322, length = 41
# [Episode  242] total reward = -115.918587, length = 42
# [Episode  243] total reward = -116.348297, length = 143
# [Episode  244] total reward = -115.439835, length = 54
# [Episode  245] total reward = -116.635422, length = 48
# [Episode  246] total reward = -118.083267, length = 123
# [Episode  247] total reward = -122.774216, length = 106
# [Episode  248] total reward = -113.374519, length = 139
# [Episode  249] total reward = -111.315628, length = 55
# [Episode  250] total reward = -110.163300, length = 55
# [Episode  251] total reward = -120.132874, length = 90
# [Episode  252] total reward = -117.460388, length = 149
# [Episode  253] total reward = -92.622482, length = 1600
# [Episode  254] total reward = -113.825111, length = 71
# [Episode  255] total reward = -114.189690, length = 103
# [Episode  256] total reward = -118.747803, length = 178
# [Episode  257] total reward = -120.743706, length = 140
# [Episode  258] total reward = -117.303787, length = 83
# [Episode  259] total reward = -115.012787, length = 119
# [Episode  260] total reward = -126.024307, length = 301
# [Episode  261] total reward = -118.033592, length = 51
# [Episode  262] total reward = -122.458672, length = 194
# [Episode  263] total reward = -116.793671, length = 79
# [Episode  264] total reward = -113.110878, length = 64
# [Episode  265] total reward = -117.839386, length = 114
# [Episode  266] total reward = -113.125328, length = 51
# [Episode  267] total reward = -115.541077, length = 42
# [Episode  268] total reward = -127.495796, length = 109
# [Episode  269] total reward = -116.226135, length = 57
# [Episode  270] total reward = -112.937996, length = 87
# [Episode  271] total reward = -113.243866, length = 75
# [Episode  272] total reward = -111.471542, length = 80
# [Episode  273] total reward = -118.096512, length = 95
# [Episode  274] total reward = -118.195854, length = 91
# [Episode  275] total reward = -120.439186, length = 51
# [Episode  276] total reward = -113.797989, length = 73
# [Episode  277] total reward = -118.530952, length = 158
# [Episode  278] total reward = -115.840591, length = 60
# [Episode  279] total reward = -120.635391, length = 117
# [Episode  280] total reward = -111.360779, length = 114
# [Episode  281] total reward = -108.277237, length = 58
# [Episode  282] total reward = -117.015450, length = 93
# [Episode  283] total reward = -123.770065, length = 137
# [Episode  284] total reward = -110.023567, length = 85
# [Episode  285] total reward = -117.174576, length = 56
# [Episode  286] total reward = -120.812874, length = 169
# [Episode  287] total reward = -89.735786, length = 1600
# [Episode  288] total reward = -132.101547, length = 255
# [Episode  289] total reward = -120.044365, length = 151
# [Episode  290] total reward = -77.063538, length = 1600
# [Episode  291] total reward = -114.481796, length = 80
# [Episode  292] total reward = -116.076416, length = 180
# [Episode  293] total reward = -116.665901, length = 59
# [Episode  294] total reward = -122.723045, length = 134
# [Episode  295] total reward = -86.508942, length = 1600
# [Episode  296] total reward = -111.481400, length = 50
# [Episode  297] total reward = -117.037903, length = 93
# [Episode  298] total reward = -121.171204, length = 101
# [Episode  299] total reward = -81.122162, length = 1600
# [Episode  300] total reward = -83.928841, length = 1600
# [Episode  301] total reward = -113.233955, length = 107
# [Episode  302] total reward = -114.890190, length = 75
# [Episode  303] total reward = -114.650375, length = 90
# [Episode  304] total reward = -87.381180, length = 1600
# [Episode  305] total reward = -84.009766, length = 1600
# [Episode  306] total reward = -79.786423, length = 1600
# [Episode  307] total reward = -118.606857, length = 74
# [Episode  308] total reward = -81.065353, length = 1600
# [Episode  309] total reward = -114.154716, length = 127
# [Episode  310] total reward = -83.173973, length = 1600
# [Episode  311] total reward = -114.091858, length = 90
# [Episode  312] total reward = -85.338257, length = 1600
# [Episode  313] total reward = -113.417191, length = 72
# [Episode  314] total reward = -93.365547, length = 1600
# [Episode  315] total reward = -111.166573, length = 82
# [Episode  316] total reward = -88.521393, length = 1600
# [Episode  317] total reward = -124.541908, length = 133
# [Episode  318] total reward = -90.391563, length = 1600
# [Episode  319] total reward = -83.903137, length = 1600
# [Episode  320] total reward = -112.169266, length = 65
# [Episode  321] total reward = -93.787651, length = 1600
# [Episode  322] total reward = -82.022667, length = 1600
# [Episode  323] total reward = -89.006790, length = 1600
# [Episode  324] total reward = -89.068146, length = 1600
# [Episode  325] total reward = -88.747894, length = 1600
# [Episode  326] total reward = -67.890549, length = 1600
# [Episode  327] total reward = -120.268517, length = 121
# [Episode  328] total reward = -84.917175, length = 1600
# [Episode  329] total reward = -92.301392, length = 1600
# [Episode  330] total reward = -89.523880, length = 1600
# [Episode  331] total reward = -81.351997, length = 1600
# [Episode  332] total reward = -80.855759, length = 1600
# [Episode  333] total reward = -82.634293, length = 1600
# [Episode  334] total reward = -82.479279, length = 1600
# [Episode  335] total reward = -65.433273, length = 1600
# [Episode  336] total reward = -113.307159, length = 69
# [Episode  337] total reward = -68.237747, length = 1600
# [Episode  338] total reward = -68.006599, length = 1600
# [Episode  339] total reward = -63.354374, length = 1600
# [Episode  340] total reward = -69.108543, length = 1600
# [Episode  341] total reward = -108.435051, length = 100
# [Episode  342] total reward = -104.774147, length = 75
# [Episode  343] total reward = -118.224449, length = 77
# [Episode  344] total reward = -121.615738, length = 56
# [Episode  345] total reward = -104.703743, length = 59
# [Episode  346] total reward = -117.730896, length = 96
# [Episode  347] total reward = -120.113861, length = 112
# [Episode  348] total reward = -69.845398, length = 1600
# [Episode  349] total reward = -59.834599, length = 1600
# [Episode  350] total reward = -76.185951, length = 1600
# [Episode  351] total reward = -70.165833, length = 1600
# [Episode  352] total reward = -65.355316, length = 1600
# [Episode  353] total reward = -58.115902, length = 1600
# [Episode  354] total reward = -56.785072, length = 1600
# [Episode  355] total reward = -110.267296, length = 63
# [Episode  356] total reward = -121.155678, length = 128
# [Episode  357] total reward = -71.591187, length = 1600
# [Episode  358] total reward = -107.991035, length = 50
# [Episode  359] total reward = -66.629364, length = 1600
# [Episode  360] total reward = -62.486507, length = 1600
# [Episode  361] total reward = -108.750626, length = 59
# [Episode  362] total reward = -155.943665, length = 1341
# [Episode  363] total reward = -117.136154, length = 528
# [Episode  364] total reward = -102.697304, length = 124
# [Episode  365] total reward = -118.969971, length = 507
# [Episode  366] total reward = -125.214882, length = 512
# [Episode  367] total reward = -101.591698, length = 94
# [Episode  368] total reward = -54.913246, length = 1600
# [Episode  369] total reward = -112.771461, length = 52
# [Episode  370] total reward = -121.312645, length = 884
# [Episode  371] total reward = -58.919807, length = 1600
# [Episode  372] total reward = -56.117474, length = 1600
# [Episode  373] total reward = -136.731628, length = 1034
# [Episode  374] total reward = -64.225937, length = 1600
# [Episode  375] total reward = -120.911980, length = 104
# [Episode  376] total reward = -62.327175, length = 1600
# [Episode  377] total reward = -156.468338, length = 1317
# [Episode  378] total reward = -51.568710, length = 1600
# [Episode  379] total reward = -146.558365, length = 1254
# [Episode  380] total reward = -108.331627, length = 76
# [Episode  381] total reward = -50.615955, length = 1600
# [Episode  382] total reward = -110.267975, length = 79
# [Episode  383] total reward = -109.247925, length = 78
# [Episode  384] total reward = -50.037216, length = 1600
# [Episode  385] total reward = -107.998703, length = 156
# [Episode  386] total reward = -105.574814, length = 107
# [Episode  387] total reward = -39.741211, length = 1600
# [Episode  388] total reward = -123.918495, length = 787
# [Episode  389] total reward = -108.134888, length = 252
# [Episode  390] total reward = -100.487961, length = 138
# [Episode  391] total reward = -101.650787, length = 88
# [Episode  392] total reward = -102.679817, length = 74
# [Episode  393] total reward = -120.709503, length = 562
# [Episode  394] total reward = -116.840538, length = 542
# [Episode  395] total reward = -109.780251, length = 332
# [Episode  396] total reward = -149.655777, length = 1113
# [Episode  397] total reward = -114.918869, length = 299
# [Episode  398] total reward = -101.281143, length = 133
# [Episode  399] total reward = -102.187035, length = 136
# [Episode  400] total reward = -112.579491, length = 212
#
# [  400 /  5000]
# ----------------------------------
# actor loss = -0.186754
# critic loss = 280.331268
# entropy = 5.515315
# mean return = -209.878586
# mean length = 1105.73
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -39.419019, length = 1600
# 100%|██████████| 1602/1602 [00:05<00:00, 282.39it/s]
# [Episode  401] total reward = -97.323479, length = 209
# [Episode  402] total reward = -106.035347, length = 347
# [Episode  403] total reward = -127.819344, length = 1348
# [Episode  404] total reward = -104.311462, length = 65
# [Episode  405] total reward = -106.309433, length = 69
# [Episode  406] total reward = -104.712723, length = 87
# [Episode  407] total reward = -122.692680, length = 137
# [Episode  408] total reward = -57.118557, length = 1600
# [Episode  409] total reward = -126.016846, length = 608
# [Episode  410] total reward = -113.879257, length = 287
# [Episode  411] total reward = -113.287262, length = 62
# [Episode  412] total reward = -124.217232, length = 101
# [Episode  413] total reward = -108.233711, length = 85
# [Episode  414] total reward = -110.613312, length = 76
# [Episode  415] total reward = -115.312607, length = 76
# [Episode  416] total reward = -125.421692, length = 795
# [Episode  417] total reward = -148.787994, length = 1320
# [Episode  418] total reward = -112.943146, length = 87
# [Episode  419] total reward = -119.713890, length = 608
# [Episode  420] total reward = -122.694115, length = 128
# [Episode  421] total reward = -112.427338, length = 62
# [Episode  422] total reward = -106.921234, length = 376
# [Episode  423] total reward = -111.406456, length = 76
# [Episode  424] total reward = -100.748039, length = 162
# [Episode  425] total reward = -94.816010, length = 159
# [Episode  426] total reward = -109.050751, length = 78
# [Episode  427] total reward = -109.614296, length = 143
# [Episode  428] total reward = -103.404312, length = 454
# [Episode  429] total reward = -105.586212, length = 105
# [Episode  430] total reward = -104.948799, length = 74
# [Episode  431] total reward = -111.566704, length = 58
# [Episode  432] total reward = -114.973862, length = 117
# [Episode  433] total reward = -106.809837, length = 55
# [Episode  434] total reward = -110.820297, length = 49
# [Episode  435] total reward = -108.385910, length = 43
# [Episode  436] total reward = -110.850624, length = 47
# [Episode  437] total reward = -103.306198, length = 84
# [Episode  438] total reward = -112.169228, length = 72
# [Episode  439] total reward = -108.193161, length = 98
# [Episode  440] total reward = -107.252968, length = 76
# [Episode  441] total reward = -105.985535, length = 57
# [Episode  442] total reward = -114.751984, length = 104
# [Episode  443] total reward = -108.566498, length = 50
# [Episode  444] total reward = -103.657051, length = 244
# [Episode  445] total reward = -107.448883, length = 64
# [Episode  446] total reward = -104.724869, length = 161
# [Episode  447] total reward = -101.538559, length = 103
# [Episode  448] total reward = -109.276947, length = 81
# [Episode  449] total reward = -113.872963, length = 85
# [Episode  450] total reward = -118.133286, length = 81
# [Episode  451] total reward = -108.545609, length = 57
# [Episode  452] total reward = -117.952492, length = 71
# [Episode  453] total reward = -113.639900, length = 63
# [Episode  454] total reward = -126.339737, length = 84
# [Episode  455] total reward = -114.929352, length = 215
# [Episode  456] total reward = -98.128815, length = 524
# [Episode  457] total reward = -109.978149, length = 52
# [Episode  458] total reward = -110.428185, length = 88
# [Episode  459] total reward = -89.213989, length = 1600
# [Episode  460] total reward = -96.443565, length = 226
# [Episode  461] total reward = -106.194633, length = 80
# [Episode  462] total reward = -107.887817, length = 56
# [Episode  463] total reward = -115.758018, length = 186
# [Episode  464] total reward = -30.760262, length = 1600
# [Episode  465] total reward = -107.949493, length = 64
# [Episode  466] total reward = -120.308701, length = 96
# [Episode  467] total reward = -100.567932, length = 67
# [Episode  468] total reward = -115.999367, length = 72
# [Episode  469] total reward = -106.897346, length = 56
# [Episode  470] total reward = -112.070984, length = 48
# [Episode  471] total reward = -126.247345, length = 125
# [Episode  472] total reward = -103.502380, length = 87
# [Episode  473] total reward = -108.213425, length = 56
# [Episode  474] total reward = -107.885780, length = 63
# [Episode  475] total reward = -115.105835, length = 821
# [Episode  476] total reward = -107.549431, length = 52
# [Episode  477] total reward = -110.187866, length = 59
# [Episode  478] total reward = -101.089264, length = 73
# [Episode  479] total reward = -124.178841, length = 85
# [Episode  480] total reward = -114.852829, length = 107
# [Episode  481] total reward = -106.263077, length = 947
# [Episode  482] total reward = -114.724113, length = 201
# [Episode  483] total reward = -122.635880, length = 135
# [Episode  484] total reward = -97.752251, length = 76
# [Episode  485] total reward = -104.767517, length = 49
# [Episode  486] total reward = -101.611549, length = 63
# [Episode  487] total reward = -82.106895, length = 1600
# [Episode  488] total reward = -27.043497, length = 1600
# [Episode  489] total reward = -109.575516, length = 617
# [Episode  490] total reward = -109.309319, length = 68
# [Episode  491] total reward = -110.597916, length = 389
# [Episode  492] total reward = -104.319946, length = 59
# [Episode  493] total reward = -104.586319, length = 54
# [Episode  494] total reward = -118.050934, length = 78
# [Episode  495] total reward = -101.867752, length = 91
# [Episode  496] total reward = -102.197906, length = 105
# [Episode  497] total reward = -117.378685, length = 86
# [Episode  498] total reward = -119.910965, length = 94
# [Episode  499] total reward = -27.331177, length = 1600
# [Episode  500] total reward = -20.965111, length = 1600
# [Episode  501] total reward = -120.138580, length = 76
# [Episode  502] total reward = -101.526627, length = 69
# [Episode  503] total reward = -116.034134, length = 84
# [Episode  504] total reward = -110.932777, length = 132
# [Episode  505] total reward = -79.416870, length = 1600
# [Episode  506] total reward = -149.486343, length = 1027
# [Episode  507] total reward = -118.531532, length = 80
# [Episode  508] total reward = -112.400764, length = 130
# [Episode  509] total reward = -104.508163, length = 90
# [Episode  510] total reward = -104.574043, length = 374
# [Episode  511] total reward = -122.155815, length = 94
# [Episode  512] total reward = -101.553024, length = 65
# [Episode  513] total reward = -115.188385, length = 78
# [Episode  514] total reward = -100.705948, length = 79
# [Episode  515] total reward = -107.065407, length = 59
# [Episode  516] total reward = -103.686104, length = 62
# [Episode  517] total reward = -103.778282, length = 61
# [Episode  518] total reward = -103.138313, length = 65
# [Episode  519] total reward = -98.963829, length = 66
# [Episode  520] total reward = -102.610008, length = 73
# [Episode  521] total reward = -97.792458, length = 118
# [Episode  522] total reward = -105.589157, length = 70
# [Episode  523] total reward = -101.677635, length = 69
# [Episode  524] total reward = -103.700150, length = 64
# [Episode  525] total reward = -132.230560, length = 140
# [Episode  526] total reward = -105.791504, length = 63
# [Episode  527] total reward = -82.333092, length = 1600
# [Episode  528] total reward = -38.150497, length = 1600
# [Episode  529] total reward = -104.940987, length = 60
# [Episode  530] total reward = -106.259285, length = 66
# [Episode  531] total reward = -100.858551, length = 62
# [Episode  532] total reward = -106.791740, length = 47
# [Episode  533] total reward = -98.802208, length = 280
# [Episode  534] total reward = -101.011063, length = 94
# [Episode  535] total reward = -99.586510, length = 60
# [Episode  536] total reward = -128.169052, length = 141
# [Episode  537] total reward = -117.790619, length = 69
# [Episode  538] total reward = -105.844101, length = 53
# [Episode  539] total reward = -19.478132, length = 1600
# [Episode  540] total reward = -101.949638, length = 51
# [Episode  541] total reward = -103.422478, length = 86
# [Episode  542] total reward = -43.526787, length = 1600
# [Episode  543] total reward = -40.290894, length = 1600
# [Episode  544] total reward = -120.403473, length = 106
# [Episode  545] total reward = -32.496990, length = 1600
# [Episode  546] total reward = -104.899635, length = 68
# [Episode  547] total reward = -119.250710, length = 807
# [Episode  548] total reward = -106.328270, length = 129
# [Episode  549] total reward = -127.249451, length = 105
# [Episode  550] total reward = -117.249008, length = 749
# [Episode  551] total reward = -102.072006, length = 94
# [Episode  552] total reward = -102.304298, length = 66
# [Episode  553] total reward = -103.382393, length = 50
# [Episode  554] total reward = -101.534805, length = 57
# [Episode  555] total reward = -104.225327, length = 106
# [Episode  556] total reward = -49.997185, length = 1600
# [Episode  557] total reward = -107.284187, length = 87
# [Episode  558] total reward = -106.285126, length = 78
# [Episode  559] total reward = -105.245789, length = 84
# [Episode  560] total reward = -113.800468, length = 113
# [Episode  561] total reward = -122.340302, length = 800
# [Episode  562] total reward = -102.426865, length = 61
# [Episode  563] total reward = -103.777191, length = 72
# [Episode  564] total reward = -106.644226, length = 130
# [Episode  565] total reward = -108.866837, length = 115
# [Episode  566] total reward = -104.189392, length = 86
# [Episode  567] total reward = -102.656448, length = 74
# [Episode  568] total reward = -102.534012, length = 58
# [Episode  569] total reward = -136.713455, length = 187
# [Episode  570] total reward = -126.639023, length = 132
# [Episode  571] total reward = -102.533020, length = 61
# [Episode  572] total reward = -102.347672, length = 85
# [Episode  573] total reward = -101.597870, length = 54
# [Episode  574] total reward = -35.979622, length = 1600
# [Episode  575] total reward = -111.887459, length = 427
# [Episode  576] total reward = -106.423019, length = 44
# [Episode  577] total reward = -125.611404, length = 827
# [Episode  578] total reward = -105.620193, length = 93
# [Episode  579] total reward = -103.375397, length = 42
# [Episode  580] total reward = -103.906677, length = 56
# [Episode  581] total reward = -105.130043, length = 79
# [Episode  582] total reward = -107.603348, length = 64
# [Episode  583] total reward = -126.170921, length = 171
# [Episode  584] total reward = -107.871696, length = 87
# [Episode  585] total reward = -101.687683, length = 67
# [Episode  586] total reward = -102.511513, length = 79
# [Episode  587] total reward = -100.205345, length = 66
# [Episode  588] total reward = -112.385864, length = 55
# [Episode  589] total reward = -37.708748, length = 1600
# [Episode  590] total reward = -102.476097, length = 102
# [Episode  591] total reward = -34.360634, length = 1600
# [Episode  592] total reward = -99.350807, length = 138
# [Episode  593] total reward = -103.209145, length = 116
# [Episode  594] total reward = -103.114914, length = 70
# [Episode  595] total reward = -134.650024, length = 149
# [Episode  596] total reward = -101.580032, length = 67
# [Episode  597] total reward = -104.852547, length = 71
# [Episode  598] total reward = -104.405602, length = 51
# [Episode  599] total reward = -102.180809, length = 66
# [Episode  600] total reward = -105.246193, length = 62
#
# [  600 /  5000]
# ----------------------------------
# actor loss = -0.062385
# critic loss = 1049.977417
# entropy = 5.566616
# mean return = -207.996198
# mean length = 574.78
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -100.683804, length = 130
# 100%|██████████| 132/132 [00:00<00:00, 262.32it/s]
# [Episode  601] total reward = -101.599030, length = 70
# [Episode  602] total reward = -126.616035, length = 102
# [Episode  603] total reward = -100.580605, length = 61
# [Episode  604] total reward = -101.444206, length = 86
# [Episode  605] total reward = -30.638226, length = 1600
# [Episode  606] total reward = -21.123402, length = 1600
# [Episode  607] total reward = -101.847023, length = 77
# [Episode  608] total reward = -104.334465, length = 72
# [Episode  609] total reward = -103.027351, length = 69
# [Episode  610] total reward = -32.036919, length = 1600
# [Episode  611] total reward = -100.932854, length = 60
# [Episode  612] total reward = -101.684235, length = 60
# [Episode  613] total reward = -102.710251, length = 78
# [Episode  614] total reward = -99.627411, length = 88
# [Episode  615] total reward = -106.355431, length = 111
# [Episode  616] total reward = -107.997169, length = 101
# [Episode  617] total reward = -122.544640, length = 93
# [Episode  618] total reward = -102.227211, length = 74
# [Episode  619] total reward = -31.557568, length = 1600
# [Episode  620] total reward = -121.959915, length = 88
# [Episode  621] total reward = -101.130936, length = 61
# [Episode  622] total reward = -51.285057, length = 1600
# [Episode  623] total reward = -47.344032, length = 1600
# [Episode  624] total reward = -104.693253, length = 105
# [Episode  625] total reward = -53.410828, length = 1600
# [Episode  626] total reward = -102.971657, length = 65
# [Episode  627] total reward = -43.989174, length = 1600
# [Episode  628] total reward = -63.100197, length = 1600
# [Episode  629] total reward = -37.941055, length = 1600
# [Episode  630] total reward = -107.829437, length = 59
# [Episode  631] total reward = -106.484535, length = 111
# [Episode  632] total reward = -106.166153, length = 53
# [Episode  633] total reward = -52.644981, length = 1600
# [Episode  634] total reward = -48.043396, length = 1600
# [Episode  635] total reward = -43.772980, length = 1600
# [Episode  636] total reward = -36.068897, length = 1600
# [Episode  637] total reward = -37.609825, length = 1600
# [Episode  638] total reward = -110.552757, length = 53
# [Episode  639] total reward = -39.621910, length = 1600
# [Episode  640] total reward = -36.605782, length = 1600
# [Episode  641] total reward = -33.733246, length = 1600
# [Episode  642] total reward = -38.043655, length = 1600
# [Episode  643] total reward = -42.477154, length = 1600
# [Episode  644] total reward = -34.047188, length = 1600
# [Episode  645] total reward = -38.298721, length = 1600
# [Episode  646] total reward = -30.170151, length = 1600
# [Episode  647] total reward = -37.651142, length = 1600
# [Episode  648] total reward = -32.181725, length = 1600
# [Episode  649] total reward = -103.781281, length = 104
# [Episode  650] total reward = -24.895498, length = 1600
# [Episode  651] total reward = -104.560623, length = 56
# [Episode  652] total reward = -100.844627, length = 75
# [Episode  653] total reward = -107.556900, length = 66
# [Episode  654] total reward = -31.949953, length = 1600
# [Episode  655] total reward = -107.800064, length = 320
# [Episode  656] total reward = -110.949852, length = 279
# [Episode  657] total reward = -101.734749, length = 461
# [Episode  658] total reward = -33.672749, length = 1600
# [Episode  659] total reward = 10.698765, length = 1600
# [Episode  660] total reward = -110.880028, length = 182
# [Episode  661] total reward = -103.506943, length = 59
# [Episode  662] total reward = -101.505791, length = 295
# [Episode  663] total reward = -102.803497, length = 44
# [Episode  664] total reward = -107.488922, length = 304
# [Episode  665] total reward = -116.342552, length = 311
# [Episode  666] total reward = -109.923820, length = 90
# [Episode  667] total reward = -107.050774, length = 242
# [Episode  668] total reward = -99.877922, length = 147
# [Episode  669] total reward = -113.100334, length = 231
# [Episode  670] total reward = -107.506767, length = 242
# [Episode  671] total reward = -98.018669, length = 111
# [Episode  672] total reward = -104.170441, length = 66
# [Episode  673] total reward = -98.170273, length = 113
# [Episode  674] total reward = -104.184120, length = 143
# [Episode  675] total reward = -90.591187, length = 833
# [Episode  676] total reward = -97.812790, length = 639
# [Episode  677] total reward = -15.277188, length = 1600
# [Episode  678] total reward = -108.484291, length = 76
# [Episode  679] total reward = -8.123154, length = 1600
# [Episode  680] total reward = -113.225311, length = 77
# [Episode  681] total reward = 6.227464, length = 1600
# [Episode  682] total reward = -11.414017, length = 1600
# [Episode  683] total reward = -97.074493, length = 337
# [Episode  684] total reward = -99.713646, length = 633
# [Episode  685] total reward = 2.643019, length = 1600
# [Episode  686] total reward = -3.626215, length = 1600
# [Episode  687] total reward = -101.958565, length = 1330
# [Episode  688] total reward = -94.114075, length = 1397
# [Episode  689] total reward = -101.197281, length = 114
# [Episode  690] total reward = -7.036673, length = 1600
# [Episode  691] total reward = -101.097832, length = 78
# [Episode  692] total reward = -100.220421, length = 752
# [Episode  693] total reward = -5.163381, length = 1600
# [Episode  694] total reward = -101.993408, length = 67
# [Episode  695] total reward = -102.834625, length = 68
# [Episode  696] total reward = -103.810951, length = 69
# [Episode  697] total reward = -101.575142, length = 1562
# [Episode  698] total reward = -100.414894, length = 71
# [Episode  699] total reward = -79.819031, length = 1521
# [Episode  700] total reward = -92.059425, length = 490
# [Episode  701] total reward = -105.707893, length = 55
# [Episode  702] total reward = -6.756279, length = 1600
# [Episode  703] total reward = -95.262604, length = 637
# [Episode  704] total reward = -121.215515, length = 100
# [Episode  705] total reward = -115.679428, length = 396
# [Episode  706] total reward = -109.510971, length = 1330
# [Episode  707] total reward = -104.466454, length = 70
# [Episode  708] total reward = -107.567139, length = 60
# [Episode  709] total reward = 20.694260, length = 1600
# [Episode  710] total reward = -105.811684, length = 74
# [Episode  711] total reward = -102.935226, length = 129
# [Episode  712] total reward = -100.670532, length = 1271
# [Episode  713] total reward = -105.871620, length = 76
# [Episode  714] total reward = -110.099937, length = 788
# [Episode  715] total reward = -112.163086, length = 549
# [Episode  716] total reward = -112.333923, length = 63
# [Episode  717] total reward = -97.605255, length = 472
# [Episode  718] total reward = -101.496475, length = 1195
# [Episode  719] total reward = 10.549294, length = 1600
# [Episode  720] total reward = 21.870850, length = 1600
# [Episode  721] total reward = -104.182144, length = 56
# [Episode  722] total reward = 26.040964, length = 1600
# [Episode  723] total reward = -102.505180, length = 120
# [Episode  724] total reward = -80.764740, length = 899
# [Episode  725] total reward = -81.452271, length = 1517
# [Episode  726] total reward = -105.821938, length = 72
# [Episode  727] total reward = 28.599997, length = 1600
# [Episode  728] total reward = -105.697914, length = 96
# [Episode  729] total reward = -96.089119, length = 1346
# [Episode  730] total reward = -108.140457, length = 67
# [Episode  731] total reward = -25.660908, length = 1600
# [Episode  732] total reward = -98.775215, length = 370
# [Episode  733] total reward = -108.410690, length = 61
# [Episode  734] total reward = 45.940262, length = 1600
# [Episode  735] total reward = -117.563072, length = 138
# [Episode  736] total reward = -83.901344, length = 642
# [Episode  737] total reward = -87.906425, length = 565
# [Episode  738] total reward = -108.481880, length = 62
# [Episode  739] total reward = -98.176727, length = 465
# [Episode  740] total reward = -113.645828, length = 201
# [Episode  741] total reward = -112.084412, length = 74
# [Episode  742] total reward = -99.273666, length = 397
# [Episode  743] total reward = -108.517883, length = 59
# [Episode  744] total reward = 53.213860, length = 1600
# [Episode  745] total reward = -96.490654, length = 506
# [Episode  746] total reward = 46.493729, length = 1600
# [Episode  747] total reward = 67.134087, length = 1600
# [Episode  748] total reward = -117.478943, length = 484
# [Episode  749] total reward = -107.780479, length = 51
# [Episode  750] total reward = -105.589752, length = 154
# [Episode  751] total reward = -124.212448, length = 114
# [Episode  752] total reward = -80.691841, length = 585
# [Episode  753] total reward = 51.613014, length = 1600
# [Episode  754] total reward = -104.455696, length = 100
# [Episode  755] total reward = -80.432060, length = 563
# [Episode  756] total reward = -91.226097, length = 560
# [Episode  757] total reward = 50.076195, length = 1600
# [Episode  758] total reward = 56.769016, length = 1600
# [Episode  759] total reward = -118.539146, length = 120
# [Episode  760] total reward = -94.323914, length = 335
# [Episode  761] total reward = -104.449516, length = 73
# [Episode  762] total reward = 63.376919, length = 1600
# [Episode  763] total reward = -110.076721, length = 55
# [Episode  764] total reward = -97.826645, length = 167
# [Episode  765] total reward = 35.373253, length = 1600
# [Episode  766] total reward = -38.190334, length = 1257
# [Episode  767] total reward = 51.710236, length = 1600
# [Episode  768] total reward = 58.274170, length = 1600
# [Episode  769] total reward = -108.281830, length = 223
# [Episode  770] total reward = 70.522133, length = 1600
# [Episode  771] total reward = -62.307404, length = 957
# [Episode  772] total reward = 91.945190, length = 1600
# [Episode  773] total reward = 71.179871, length = 1600
# [Episode  774] total reward = -49.661755, length = 1508
# [Episode  775] total reward = -80.255951, length = 805
# [Episode  776] total reward = 20.073082, length = 1600
# [Episode  777] total reward = 57.999012, length = 1600
# [Episode  778] total reward = -109.997231, length = 60
# [Episode  779] total reward = -89.539909, length = 764
# [Episode  780] total reward = -67.357529, length = 881
# [Episode  781] total reward = -107.828506, length = 48
# [Episode  782] total reward = -63.654823, length = 664
# [Episode  783] total reward = -110.428505, length = 75
# [Episode  784] total reward = -105.289421, length = 52
# [Episode  785] total reward = 86.294479, length = 1600
# [Episode  786] total reward = -116.255234, length = 65
# [Episode  787] total reward = -48.111073, length = 1408
# [Episode  788] total reward = -92.174072, length = 902
# [Episode  789] total reward = -67.069717, length = 509
# [Episode  790] total reward = 81.327789, length = 1600
# [Episode  791] total reward = -115.367165, length = 135
# [Episode  792] total reward = -78.626572, length = 400
# [Episode  793] total reward = 60.114098, length = 1600
# [Episode  794] total reward = 67.731201, length = 1600
# [Episode  795] total reward = 71.215919, length = 1600
# [Episode  796] total reward = -44.600204, length = 1228
# [Episode  797] total reward = 90.246048, length = 1600
# [Episode  798] total reward = 58.937271, length = 1600
# [Episode  799] total reward = 86.333923, length = 1600
# [Episode  800] total reward = 70.671463, length = 1600
#
# [  800 /  5000]
# ----------------------------------
# actor loss = -0.188950
# critic loss = 0.168141
# entropy = 5.518619
# mean return = -126.485151
# mean length = 1565.32
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 1.536793, length = 1600
# 100%|██████████| 1602/1602 [00:06<00:00, 262.53it/s]
# [Episode  801] total reward = -83.372337, length = 908
# [Episode  802] total reward = -109.947975, length = 298
# [Episode  803] total reward = -120.294868, length = 82
# [Episode  804] total reward = -72.793877, length = 460
# [Episode  805] total reward = 97.848083, length = 1600
# [Episode  806] total reward = -120.514351, length = 105
# [Episode  807] total reward = -81.004890, length = 606
# [Episode  808] total reward = -91.148796, length = 339
# [Episode  809] total reward = -98.045578, length = 132
# [Episode  810] total reward = 98.031242, length = 1600
# [Episode  811] total reward = -108.155602, length = 90
# [Episode  812] total reward = 81.192062, length = 1600
# [Episode  813] total reward = -87.391319, length = 482
# [Episode  814] total reward = -117.835686, length = 102
# [Episode  815] total reward = -120.907082, length = 134
# [Episode  816] total reward = -45.413712, length = 684
# [Episode  817] total reward = -80.282288, length = 801
# [Episode  818] total reward = 61.341778, length = 1600
# [Episode  819] total reward = -107.515747, length = 82
# [Episode  820] total reward = -59.153915, length = 642
# [Episode  821] total reward = -98.149918, length = 321
# [Episode  822] total reward = 70.873772, length = 1600
# [Episode  823] total reward = 75.900986, length = 1600
# [Episode  824] total reward = -25.423004, length = 1503
# [Episode  825] total reward = -75.848572, length = 367
# [Episode  826] total reward = -34.709179, length = 1117
# [Episode  827] total reward = -91.647171, length = 727
# [Episode  828] total reward = -43.915501, length = 842
# [Episode  829] total reward = 66.896370, length = 1600
# [Episode  830] total reward = -46.869144, length = 1462
# [Episode  831] total reward = 108.992165, length = 1600
# [Episode  832] total reward = -112.516266, length = 66
# [Episode  833] total reward = -124.839729, length = 111
# [Episode  834] total reward = -65.764854, length = 700
# [Episode  835] total reward = -98.897133, length = 129
# [Episode  836] total reward = -54.395180, length = 918
# [Episode  837] total reward = -44.606529, length = 1551
# ...
# [Episode 4717] total reward = 253.909134, length = 1112
# [Episode 4718] total reward = 72.582596, length = 962
# [Episode 4719] total reward = 256.936462, length = 1084
# [Episode 4720] total reward = 251.748749, length = 1141
# [Episode 4721] total reward = 255.367493, length = 1096
# [Episode 4722] total reward = 253.842865, length = 1108
# [Episode 4723] total reward = -41.828964, length = 469
# [Episode 4724] total reward = 89.668747, length = 910
# [Episode 4725] total reward = 251.420395, length = 1143
# [Episode 4726] total reward = 249.005737, length = 1167
# [Episode 4727] total reward = 259.832214, length = 1051
# [Episode 4728] total reward = 80.686172, length = 835
# [Episode 4729] total reward = 256.414032, length = 1093
# [Episode 4730] total reward = 254.544861, length = 1113
# [Episode 4731] total reward = 253.680466, length = 1081
# [Episode 4732] total reward = 252.376465, length = 1139
# [Episode 4733] total reward = 247.947647, length = 1172
# [Episode 4734] total reward = 257.714111, length = 1082
# [Episode 4735] total reward = 252.751740, length = 1126
# [Episode 4736] total reward = 260.962677, length = 1039
# [Episode 4737] total reward = 256.047424, length = 1091
# [Episode 4738] total reward = 260.681885, length = 1037
# [Episode 4739] total reward = 254.502182, length = 1107
# [Episode 4740] total reward = 90.966568, length = 813
# [Episode 4741] total reward = -37.701691, length = 267
# [Episode 4742] total reward = 258.255432, length = 1055
# [Episode 4743] total reward = -68.763214, length = 179
# [Episode 4744] total reward = 75.954071, length = 727
# [Episode 4745] total reward = 252.717224, length = 1134
# [Episode 4746] total reward = -13.449329, length = 396
# [Episode 4747] total reward = 251.730118, length = 1130
# [Episode 4748] total reward = 252.736160, length = 1122
# [Episode 4749] total reward = -3.984150, length = 479
# [Episode 4750] total reward = -12.003525, length = 435
# [Episode 4751] total reward = 244.834045, length = 1203
# [Episode 4752] total reward = -124.917557, length = 48
# [Episode 4753] total reward = 244.272751, length = 1212
# [Episode 4754] total reward = 258.526733, length = 1063
# [Episode 4755] total reward = 250.813065, length = 1119
# [Episode 4756] total reward = -28.165781, length = 314
# [Episode 4757] total reward = 260.659058, length = 1037
# [Episode 4758] total reward = 257.782776, length = 1076
# [Episode 4759] total reward = 43.390305, length = 696
# [Episode 4760] total reward = 254.451447, length = 1094
# [Episode 4761] total reward = 260.278137, length = 1037
# [Episode 4762] total reward = 237.950394, length = 1280
# [Episode 4763] total reward = 257.044708, length = 1078
# [Episode 4764] total reward = 90.980789, length = 757
# [Episode 4765] total reward = 253.096054, length = 1122
# [Episode 4766] total reward = 66.772064, length = 691
# [Episode 4767] total reward = -43.726707, length = 299
# [Episode 4768] total reward = 22.870640, length = 635
# [Episode 4769] total reward = 258.963318, length = 1044
# [Episode 4770] total reward = -85.125305, length = 228
# [Episode 4771] total reward = -26.062563, length = 443
# [Episode 4772] total reward = 253.996155, length = 1107
# [Episode 4773] total reward = 259.029419, length = 1045
# [Episode 4774] total reward = 262.209778, length = 1002
# [Episode 4775] total reward = -25.184858, length = 353
# [Episode 4776] total reward = 258.314331, length = 1065
# [Episode 4777] total reward = 254.130524, length = 1101
# [Episode 4778] total reward = 248.263351, length = 1172
# [Episode 4779] total reward = 253.782715, length = 1102
# [Episode 4780] total reward = 258.769836, length = 1057
# [Episode 4781] total reward = 250.649200, length = 1130
# [Episode 4782] total reward = -59.544003, length = 206
# [Episode 4783] total reward = 44.958721, length = 664
# [Episode 4784] total reward = 242.700592, length = 1216
# [Episode 4785] total reward = 146.326691, length = 1124
# [Episode 4786] total reward = -114.420517, length = 150
# [Episode 4787] total reward = 250.935333, length = 1144
# [Episode 4788] total reward = 253.113235, length = 1118
# [Episode 4789] total reward = 108.974792, length = 814
# [Episode 4790] total reward = 254.103958, length = 1105
# [Episode 4791] total reward = -21.705793, length = 374
# [Episode 4792] total reward = -62.770721, length = 179
# [Episode 4793] total reward = -44.600670, length = 273
# [Episode 4794] total reward = 255.996674, length = 1087
# [Episode 4795] total reward = 261.144348, length = 1031
# [Episode 4796] total reward = 59.406902, length = 693
# [Episode 4797] total reward = 30.402660, length = 571
# [Episode 4798] total reward = -33.849377, length = 339
# [Episode 4799] total reward = 62.248753, length = 656
# [Episode 4800] total reward = -75.204094, length = 157
#
# [ 4800 /  5000]
# ----------------------------------
# actor loss = 0.015121
# critic loss = 646.955688
# entropy = 6.230288
# mean return = 254.070027
# mean length = 1605.32
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 262.499245, length = 1006
# 100%|██████████| 1008/1008 [00:04<00:00, 239.38it/s]
# [Episode 4801] total reward = 257.988037, length = 1067
# [Episode 4802] total reward = 259.735229, length = 1046
# [Episode 4803] total reward = 156.606216, length = 1043
# [Episode 4804] total reward = 143.503250, length = 1035
# [Episode 4805] total reward = -46.008705, length = 251
# [Episode 4806] total reward = 260.293640, length = 1033
# [Episode 4807] total reward = 251.653137, length = 1126
# [Episode 4808] total reward = -79.600502, length = 139
# [Episode 4809] total reward = 22.977398, length = 509
# [Episode 4810] total reward = 87.512497, length = 794
# [Episode 4811] total reward = 258.719391, length = 1058
# [Episode 4812] total reward = 4.547318, length = 451
# [Episode 4813] total reward = -53.362183, length = 239
# [Episode 4814] total reward = 256.162903, length = 1082
# [Episode 4815] total reward = 252.736618, length = 1123
# [Episode 4816] total reward = 20.940910, length = 561
# [Episode 4817] total reward = -0.508469, length = 506
# [Episode 4818] total reward = 76.925415, length = 795
# [Episode 4819] total reward = 138.825378, length = 1012
# [Episode 4820] total reward = -40.182755, length = 303
# [Episode 4821] total reward = 255.384094, length = 1087
# [Episode 4822] total reward = 259.678223, length = 1034
# [Episode 4823] total reward = 11.064247, length = 491
# [Episode 4824] total reward = -42.150955, length = 305
# [Episode 4825] total reward = 9.633865, length = 509
# [Episode 4826] total reward = 9.040909, length = 519
# [Episode 4827] total reward = 31.354111, length = 560
# [Episode 4828] total reward = -1.694969, length = 433
# [Episode 4829] total reward = -21.074100, length = 443
# [Episode 4830] total reward = 254.342865, length = 1107
# [Episode 4831] total reward = 122.878563, length = 867
# [Episode 4832] total reward = 124.261604, length = 932
# [Episode 4833] total reward = 257.397217, length = 1083
# [Episode 4834] total reward = 246.253006, length = 1189
# [Episode 4835] total reward = 37.189636, length = 651
# [Episode 4836] total reward = 128.068817, length = 1073
# [Episode 4837] total reward = -56.849960, length = 208
# [Episode 4838] total reward = -22.533264, length = 306
# [Episode 4839] total reward = -76.642723, length = 202
# [Episode 4840] total reward = -134.222824, length = 179
# [Episode 4841] total reward = -24.746956, length = 380
# [Episode 4842] total reward = 119.710274, length = 1011
# [Episode 4843] total reward = 256.014648, length = 1076
# [Episode 4844] total reward = 47.521126, length = 750
# [Episode 4845] total reward = 261.464661, length = 1041
# [Episode 4846] total reward = 250.148499, length = 1153
# [Episode 4847] total reward = 259.321228, length = 1075
# [Episode 4848] total reward = -24.827145, length = 374
# [Episode 4849] total reward = 36.755455, length = 577
# [Episode 4850] total reward = 62.706505, length = 759
# [Episode 4851] total reward = 258.284760, length = 1065
# [Episode 4852] total reward = -76.178833, length = 171
# [Episode 4853] total reward = -67.086761, length = 175
# [Episode 4854] total reward = 257.359161, length = 1086
# [Episode 4855] total reward = -121.602310, length = 111
# [Episode 4856] total reward = 80.486328, length = 799
# [Episode 4857] total reward = 7.841785, length = 478
# [Episode 4858] total reward = 17.377647, length = 471
# [Episode 4859] total reward = 142.838272, length = 1151
# [Episode 4860] total reward = 11.074844, length = 437
# [Episode 4861] total reward = -40.121445, length = 301
# [Episode 4862] total reward = 91.305542, length = 864
# [Episode 4863] total reward = 106.009659, length = 803
# [Episode 4864] total reward = 104.838943, length = 858
# [Episode 4865] total reward = -124.856247, length = 121
# [Episode 4866] total reward = 250.752274, length = 1144
# [Episode 4867] total reward = 52.166828, length = 630
# [Episode 4868] total reward = -124.619659, length = 176
# [Episode 4869] total reward = 245.296814, length = 1197
# [Episode 4870] total reward = 256.362244, length = 1089
# [Episode 4871] total reward = 262.387634, length = 1021
# [Episode 4872] total reward = 254.735107, length = 1109
# [Episode 4873] total reward = 255.807861, length = 1096
# [Episode 4874] total reward = 256.137878, length = 1089
# [Episode 4875] total reward = -106.167610, length = 213
# [Episode 4876] total reward = 260.600311, length = 1044
# [Episode 4877] total reward = 89.171921, length = 883
# [Episode 4878] total reward = 141.179504, length = 1036
# [Episode 4879] total reward = 244.160187, length = 1191
# [Episode 4880] total reward = 249.016464, length = 1157
# [Episode 4881] total reward = 255.444092, length = 1095
# [Episode 4882] total reward = 253.421661, length = 1128
# [Episode 4883] total reward = 242.221588, length = 1238
# [Episode 4884] total reward = -51.507675, length = 250
# [Episode 4885] total reward = 248.604324, length = 1170
# [Episode 4886] total reward = 100.946198, length = 894
# [Episode 4887] total reward = 65.955978, length = 836
# [Episode 4888] total reward = 261.901062, length = 1032
# [Episode 4889] total reward = 249.715881, length = 1162
# [Episode 4890] total reward = 257.561829, length = 1080
# [Episode 4891] total reward = 258.958221, length = 1064
# [Episode 4892] total reward = 122.579971, length = 944
# [Episode 4893] total reward = 3.768074, length = 476
# [Episode 4894] total reward = 253.362396, length = 1140
# [Episode 4895] total reward = 120.784378, length = 1130
# [Episode 4896] total reward = 256.380035, length = 1108
# [Episode 4897] total reward = 258.818420, length = 1068
# [Episode 4898] total reward = 250.014648, length = 1176
# [Episode 4899] total reward = 254.566071, length = 1130
# [Episode 4900] total reward = 253.553680, length = 1127
# [Episode 4901] total reward = 258.299805, length = 1096
# [Episode 4902] total reward = 255.064072, length = 1125
# [Episode 4903] total reward = 259.271912, length = 1065
# [Episode 4904] total reward = 263.995880, length = 1020
# [Episode 4905] total reward = -128.554993, length = 116
# [Episode 4906] total reward = 256.127869, length = 1101
# [Episode 4907] total reward = 261.429993, length = 1046
# [Episode 4908] total reward = 247.676025, length = 1192
# [Episode 4909] total reward = 264.577576, length = 1006
# [Episode 4910] total reward = 8.266335, length = 466
# [Episode 4911] total reward = 112.703537, length = 930
# [Episode 4912] total reward = 7.231281, length = 464
# [Episode 4913] total reward = 49.321438, length = 941
# [Episode 4914] total reward = 78.358444, length = 858
# [Episode 4915] total reward = 33.744350, length = 656
# [Episode 4916] total reward = -72.906693, length = 191
# [Episode 4917] total reward = 264.574738, length = 1014
# [Episode 4918] total reward = 258.408173, length = 1093
# [Episode 4919] total reward = 257.073975, length = 1102
# [Episode 4920] total reward = -121.829018, length = 115
# [Episode 4921] total reward = 262.885742, length = 1047
# [Episode 4922] total reward = 26.844467, length = 620
# [Episode 4923] total reward = -30.817131, length = 383
# [Episode 4924] total reward = 10.139973, length = 535
# [Episode 4925] total reward = 254.745712, length = 1126
# [Episode 4926] total reward = -16.567780, length = 358
# [Episode 4927] total reward = 258.196350, length = 1077
# [Episode 4928] total reward = -27.945278, length = 317
# [Episode 4929] total reward = -64.255249, length = 190
# [Episode 4930] total reward = 99.595734, length = 732
# [Episode 4931] total reward = -15.222023, length = 399
# [Episode 4932] total reward = 259.478058, length = 1055
# [Episode 4933] total reward = 71.861053, length = 776
# [Episode 4934] total reward = 133.759323, length = 1005
# [Episode 4935] total reward = -28.077187, length = 308
# [Episode 4936] total reward = 261.138062, length = 1062
# [Episode 4937] total reward = 89.513123, length = 740
# [Episode 4938] total reward = 258.052673, length = 1094
# [Episode 4939] total reward = -8.976448, length = 417
# [Episode 4940] total reward = 120.365822, length = 1019
# [Episode 4941] total reward = 262.200806, length = 1041
# [Episode 4942] total reward = -82.717415, length = 135
# [Episode 4943] total reward = 258.837830, length = 1071
# [Episode 4944] total reward = 266.200073, length = 994
# [Episode 4945] total reward = 127.387077, length = 1014
# [Episode 4946] total reward = 26.982632, length = 565
# [Episode 4947] total reward = -57.740089, length = 275
# [Episode 4948] total reward = 260.099792, length = 1059
# [Episode 4949] total reward = 256.292877, length = 1112
# [Episode 4950] total reward = 147.641281, length = 992
# [Episode 4951] total reward = 258.202209, length = 1084
# [Episode 4952] total reward = 267.286377, length = 989
# [Episode 4953] total reward = 9.365582, length = 465
# [Episode 4954] total reward = 121.639221, length = 1020
# [Episode 4955] total reward = 125.215363, length = 953
# [Episode 4956] total reward = -55.980743, length = 217
# [Episode 4957] total reward = 119.503525, length = 916
# [Episode 4958] total reward = -74.093681, length = 161
# [Episode 4959] total reward = -1.938095, length = 445
# [Episode 4960] total reward = 8.833275, length = 507
# [Episode 4961] total reward = 252.151520, length = 1163
# [Episode 4962] total reward = 254.928696, length = 1111
# [Episode 4963] total reward = -121.105171, length = 118
# [Episode 4964] total reward = 257.944702, length = 1089
# [Episode 4965] total reward = 260.239014, length = 1061
# [Episode 4966] total reward = 59.840649, length = 630
# [Episode 4967] total reward = 251.665588, length = 1143
# [Episode 4968] total reward = 117.904083, length = 964
# [Episode 4969] total reward = 262.007202, length = 1040
# [Episode 4970] total reward = 68.048233, length = 739
# [Episode 4971] total reward = 260.175476, length = 1066
# [Episode 4972] total reward = 148.259430, length = 1048
# [Episode 4973] total reward = 153.309723, length = 994
# [Episode 4974] total reward = 71.007843, length = 683
# [Episode 4975] total reward = 112.244019, length = 893
# [Episode 4976] total reward = 258.506592, length = 1079
# [Episode 4977] total reward = 23.374496, length = 542
# [Episode 4978] total reward = 254.504608, length = 1112
# [Episode 4979] total reward = 249.357483, length = 1175
# [Episode 4980] total reward = 255.744446, length = 1101
# [Episode 4981] total reward = 26.961506, length = 555
# [Episode 4982] total reward = 150.846176, length = 983
# [Episode 4983] total reward = -57.384346, length = 246
# [Episode 4984] total reward = 249.882904, length = 1172
# [Episode 4985] total reward = 74.847260, length = 802
# [Episode 4986] total reward = 63.692059, length = 679
# [Episode 4987] total reward = -52.520237, length = 224
# [Episode 4988] total reward = 260.985718, length = 1047
# [Episode 4989] total reward = 262.165649, length = 1032
# [Episode 4990] total reward = 259.776306, length = 1042
# [Episode 4991] total reward = 24.670731, length = 497
# [Episode 4992] total reward = -16.863533, length = 380
# [Episode 4993] total reward = 260.905487, length = 1046
# [Episode 4994] total reward = 264.664246, length = 998
# [Episode 4995] total reward = 260.892517, length = 1047
# [Episode 4996] total reward = 254.155350, length = 1127
# [Episode 4997] total reward = 253.959244, length = 1125
# [Episode 4998] total reward = 262.591217, length = 1035
# [Episode 4999] total reward = 253.872818, length = 1133

# %% [markdown]
# ### 5.3 Load the Model and Play

# %%
save_dir = project_root + '/save'
model_path = os.path.join(save_dir, "model.pt")

if os.path.exists(model_path):
    print("Loading the model ... ", end="")
    checkpoint = torch.load(model_path)
    policy_net.load_state_dict(checkpoint["PolicyNet"])
    print("Done.")
else:
    print('ERROR: No model saved')

play(policy_net)
# Out:
# Loading the model ... Done.
# [Evaluation] Total reward = 85.513852, length = 758
# 100%|█████████▉| 759/760 [00:02<00:00, 257.18it/s]
