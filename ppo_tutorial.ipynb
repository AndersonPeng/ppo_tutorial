# %% [markdown]
# # Proximal Policy Optimization (PPO) Tutorial

# %% [markdown]
# ## 1. Environment Preparation

# %% [markdown]
# ### 1.1 Download Packages for BipedalWalker-v3

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# !pip install box2d-py
# !pip install 'gym[Box2D]'
# Out:
# Collecting colabgymrender==1.0.2
#   Downloading https://files.pythonhosted.org/packages/94/de/8e81910e3d36183f91738ece48a68e543cb9567e07d83022419223058d8f/colabgymrender-1.0.2.tar.gz
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (2.2)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay->colabgymrender==1.0.2) (0.3)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.41.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-cp37-none-any.whl size=2446 sha256=dd65d054c08d16709375913a090748a5dd0c5fae8941a6642a58637eea6e9e58
#   Stored in directory: /root/.cache/pip/wheels/7e/75/39/ba42a666bfb04ef568d25f43e5e963bb30c275446271085240
# Successfully built colabgymrender
# Installing collected packages: colabgymrender
# Successfully installed colabgymrender-1.0.2
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/87/34/da5393985c3ff9a76351df6127c275dcb5749ae0abbe8d5210f06d97405d/box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 5.0MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (1.5.0)
# Requirement already satisfied: box2d-py~=2.3.5; extra == "box2d" in /usr/local/lib/python3.7/dist-packages (from gym[Box2D]) (2.3.8)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box2D]) (0.16.0)

# %% [markdown]
# ### 1.2 Mount Drive and Set Project Path

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
project_root = '/content/drive/My Drive/ppo_tutorial/'
sys.path.append(project_root)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.3 Test the BipedalWalker-v3 Environment

# %%
import os
import gym
import torch
import torch.nn as nn
import numpy as np
from colabgymrender.recorder import Recorder

env = gym.make('BipedalWalker-v3')
s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
print(s_dim)
print(a_dim)
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# 24
# 4

# %% [markdown]
# ## 2. Policy Network & Value Network Construction

# %% [markdown]
# ### 2.1 Diagonal Gaussian Distribution Module

# %%
#AddBias module
class AddBias(nn.Module):
    def __init__(self, bias):
        super(AddBias, self).__init__()
        self._bias = nn.Parameter(bias.unsqueeze(1))
    
    def forward(self, x):
        bias = self._bias.t().view(1, -1)
        return x + bias

#Gaussian distribution with given mean & std.
class FixedNormal(torch.distributions.Normal):
    def log_probs(self, x):
        return super().log_prob(x).sum(-1)
    
    def entropy(self):
        return super().entropy().sum(-1)

    def mode(self):
        return self.mean

#Diagonal Gaussian module
class DiagGaussian(nn.Module):
    def __init__(self, inp_dim, out_dim):
        super(DiagGaussian, self).__init__()
        self.fc_mean = nn.Linear(inp_dim, out_dim)
        self.b_logstd = AddBias(torch.zeros(out_dim))
    
    def forward(self, x):
        mean = self.fc_mean(x)
        logstd = self.b_logstd(torch.zeros_like(mean))
        return FixedNormal(mean, logstd.exp())

# %% [markdown]
# ### 2.2 Policy Network & Value Network Module

# %%
#Policy Network
class PolicyNet(nn.Module):
    #Constructor
    def __init__(self, s_dim, a_dim):
        super(PolicyNet, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )
        self.dist = DiagGaussian(128, a_dim)
    
    #Forward pass
    def forward(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            action = dist.mode()
        else:
            action = dist.sample()
        
        return action, dist.log_probs(action)
    
    #Choose an action (stochastically or deterministically)
    def choose_action(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            return dist.mode()

        return dist.sample()
    
    #Evaluate a state-action pair (output log-prob. & entropy)
    def evaluate(self, state, action):
        feature = self.main(state)
        dist = self.dist(feature)
        return dist.log_probs(action), dist.entropy()

#Value Network
class ValueNet(nn.Module):
    #Constructor
    def __init__(self, s_dim):
        super(ValueNet, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    
    #Forward pass
    def forward(self, state):
        return self.main(state)[:, 0]

# %% [markdown]
# ### 2.3 Create Policy Network & Value Network

# %%
policy_net = PolicyNet(s_dim, a_dim)
value_net = ValueNet(s_dim)
print(policy_net)
print(value_net)
# Out:
# PolicyNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#   )
#   (dist): DiagGaussian(
#     (fc_mean): Linear(in_features=128, out_features=4, bias=True)
#     (b_logstd): AddBias()
#   )
# )
# ValueNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## 3. Environment Runner Construction

# %% [markdown]
# ### 3.1 EnvRunner Class

# %%
class EnvRunner:
    #Constructor
    def __init__(self, s_dim, a_dim, gamma=0.99, lamb=0.95, max_step=2048, device='cpu'):
        self.s_dim = s_dim
        self.a_dim = a_dim
        self.gamma = gamma
        self.lamb = lamb
        self.max_step = max_step
        self.device = device

        #Storages (state, action, value, reward, a_logp)
        self.mb_states = np.zeros((self.max_step, self.s_dim), dtype=np.float32)
        self.mb_actions = np.zeros((self.max_step, self.a_dim), dtype=np.float32)
        self.mb_values = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_rewards = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_a_logps = np.zeros((self.max_step,), dtype=np.float32)
    
    #Compute discounted return
    def compute_discounted_return(self, rewards, last_value):
        returns = np.zeros_like(rewards)
        n_step = len(rewards)

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                returns[t] = rewards[t] + self.gamma * last_value
            else:
                returns[t] = rewards[t] + self.gamma * returns[t+1]

        return returns
    
    #Compute generalized advantage estimation (Optional)
    def compute_gae(self, rewards, values, last_value):
        advs = np.zeros_like(rewards)
        n_step = len(rewards)
        last_gae_lam = 0.0

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                next_value = last_value
            else:
                next_value = values[t+1]

            delta = rewards[t] + self.gamma*next_value - values[t]
            advs[t] = last_gae_lam = delta + self.gamma*self.lamb*last_gae_lam

        return advs + values

    #Run an episode using the policy net & value net
    def run(self, env, policy_net, value_net):
        #Run an episode
        state = env.reset()   #Initial state
        episode_len = self.max_step

        for step in range(self.max_step):
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
            action, a_logp = policy_net(state_tensor)
            value = value_net(state_tensor)

            action = action.cpu().numpy()[0]
            a_logp = a_logp.cpu().numpy()
            value  = value.cpu().numpy()

            self.mb_states[step] = state
            self.mb_actions[step] = action
            self.mb_a_logps[step] = a_logp
            self.mb_values[step] = value

            state, reward, done, info = env.step(action)
            self.mb_rewards[step] = reward

            if done:
                episode_len = step + 1
                break
        
        #Compute returns
        last_value = value_net(
            torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
        ).cpu().numpy()

        mb_returns = self.compute_discounted_return(self.mb_rewards[:episode_len], last_value)
        '''
        mb_returns = self.compute_gae(
            self.mb_rewards[:episode_len], 
            self.mb_values[:episode_len],
            last_value
        )
        '''
        return self.mb_states[:episode_len], \
                self.mb_actions[:episode_len], \
                self.mb_a_logps[:episode_len], \
                self.mb_values[:episode_len], \
                mb_returns, \
                self.mb_rewards[:episode_len]

# %% [markdown]
# ### 3.2 Create EnvRunner

# %%
runner = EnvRunner(s_dim, a_dim)

# %% [markdown]
# ## 4. PPO Algorithm

# %% [markdown]
# ### 4.1 PPO Class

# %%
class PPO:
    #Constructor
    def __init__(self, policy_net, value_net, lr=1e-4, max_grad_norm=0.5, ent_weight=0.01, clip_val=0.2, sample_n_epoch=4, sample_mb_size=64, device='cpu'):
        self.policy_net = policy_net
        self.value_net = value_net
        self.max_grad_norm = max_grad_norm
        self.ent_weight = ent_weight
        self.clip_val = clip_val
        self.sample_n_epoch = sample_n_epoch
        self.sample_mb_size = sample_mb_size
        self.device = device
        self.opt_polcy = torch.optim.Adam(policy_net.parameters(), lr)
        self.opt_value = torch.optim.Adam(value_net.parameters(), lr)
    
    #Train the policy net & value net using PPO
    def train(self, mb_states, mb_actions, mb_old_values, mb_advs, mb_returns, mb_old_a_logps):
        #Convert numpy array to tensor
        mb_states = torch.from_numpy(mb_states).to(self.device)
        mb_actions = torch.from_numpy(mb_actions).to(self.device)
        mb_old_values = torch.from_numpy(mb_old_values).to(self.device)
        mb_advs = torch.from_numpy(mb_advs).to(self.device)
        mb_returns = torch.from_numpy(mb_returns).to(self.device)
        mb_old_a_logps = torch.from_numpy(mb_old_a_logps).to(self.device)
        episode_length = len(mb_states)
        rand_idx = np.arange(episode_length)
        sample_n_mb = episode_length // self.sample_mb_size

        if sample_n_mb <= 0:
            sample_mb_size = episode_length
            sample_n_mb = 1
        else:
            sample_mb_size = self.sample_mb_size

        for i in range(self.sample_n_epoch):
            np.random.shuffle(rand_idx)

            for j in range(sample_n_mb):
                #Randomly sample a batch for training
                sample_idx = rand_idx[j*sample_mb_size : (j+1)*sample_mb_size]
                sample_states = mb_states[sample_idx]
                sample_actions = mb_actions[sample_idx]
                sample_old_values = mb_old_values[sample_idx]
                sample_advs = mb_advs[sample_idx]
                sample_returns = mb_returns[sample_idx]
                sample_old_a_logps = mb_old_a_logps[sample_idx]

                sample_a_logps, sample_ents = self.policy_net.evaluate(sample_states, sample_actions)
                sample_values = self.value_net(sample_states)
                ent = sample_ents.mean()

                #Compute value loss
                v_pred_clip = sample_old_values + torch.clamp(sample_values - sample_old_values, -self.clip_val, self.clip_val)
                v_loss1 = (sample_returns - sample_values).pow(2)
                v_loss2 = (sample_returns - v_pred_clip).pow(2)
                v_loss = torch.max(v_loss1, v_loss2).mean()

                #Compute policy gradient loss
                ratio = (sample_a_logps - sample_old_a_logps).exp()
                pg_loss1 = -sample_advs * ratio
                pg_loss2 = -sample_advs * torch.clamp(ratio, 1.0-self.clip_val, 1.0+self.clip_val)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean() - self.ent_weight*ent

                #Train actor
                self.opt_polcy.zero_grad()
                pg_loss.backward()
                nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.max_grad_norm)
                self.opt_polcy.step()

                #Train critic
                self.opt_value.zero_grad()
                v_loss.backward()
                nn.utils.clip_grad_norm_(self.value_net.parameters(), self.max_grad_norm)
                self.opt_value.step()

        return pg_loss.item(), v_loss.item(), ent.item()

# %% [markdown]
# ### 4.2 Create PPO Agent

# %%
agent = PPO(policy_net, value_net)

# %% [markdown]
# ## 5. Training and Testing Process

# %% [markdown]
# ### 5.1 Play an Episode for Evaluation

# %%
def play(policy_net):
    render_env = Recorder(gym.make('BipedalWalker-v3'), project_root + '/video')

    with torch.no_grad():
        state = render_env.reset()
        total_reward = 0
        length = 0

        while True:
            #render_env.render()
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device='cpu')
            action = policy_net.choose_action(state_tensor, deterministic=True).cpu().numpy()
            state, reward, done, info = render_env.step(action[0])
            total_reward += reward
            length += 1

            if done:
                print("[Evaluation] Total reward = {:.6f}, length = {:d}".format(total_reward, length), flush=True)
                break
    render_env.play()
    render_env.close()

# %%
play(policy_net)
# Out:
# [Evaluation] Total reward = -91.896360, length = 107
#  99%|█████████▉| 108/109 [00:00<00:00, 262.70it/s]

# %% [markdown]
# ### 5.2 Train the Networks using PPO

# %%
def train(env, runner, policy_net, value_net, agent, max_episode=5000):
    mean_total_reward = 0
    mean_length = 0
    save_dir = project_root + '/save'

    if not os.path.exists(save_dir):
        os.mkdir(save_dir)

    for i in range(max_episode):
        #Run an episode to collect data
        with torch.no_grad():
            mb_states, mb_actions, mb_old_a_logps, mb_values, mb_returns, mb_rewards = runner.run(env, policy_net, value_net)
            mb_advs = mb_returns - mb_values
            mb_advs = (mb_advs - mb_advs.mean()) / (mb_advs.std() + 1e-6)
        
        #Train the model using the collected data
        pg_loss, v_loss, ent = agent.train(mb_states, mb_actions, mb_values, mb_advs, mb_returns, mb_old_a_logps)
        mean_total_reward += mb_rewards.sum()
        mean_length += len(mb_states)
        print("[Episode {:4d}] total reward = {:.6f}, length = {:d}".format(i, mb_rewards.sum(), len(mb_states)))

        #Show the current result & save the model
        if i % 200 == 0:
            print("\n[{:5d} / {:5d}]".format(i, max_episode))
            print("----------------------------------")
            print("actor loss = {:.6f}".format(pg_loss))
            print("critic loss = {:.6f}".format(v_loss))
            print("entropy = {:.6f}".format(ent))
            print("mean return = {:.6f}".format(mean_total_reward / 200))
            print("mean length = {:.2f}".format(mean_length / 200))
            print("\nSaving the model ... ", end="")
            torch.save({
                "it": i,
                "PolicyNet": policy_net.state_dict(),
                "ValueNet": value_net.state_dict()
            }, os.path.join(save_dir, "model.pt"))
            print("Done.")
            print()
            play(policy_net)
            mean_total_reward = 0
            mean_length = 0

# %%
train(env, runner, policy_net, value_net, agent)
env.close()
# Out:
# [Episode    0] total reward = -100.726105, length = 58
#
# [    0 /  5000]
# ----------------------------------
# actor loss = -0.064683
# critic loss = 5872.854004
# entropy = 5.676354
# mean return = -0.503631
# mean length = 0.29
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -92.398783, length = 106
# 100%|██████████| 108/108 [00:00<00:00, 267.36it/s]
# [Episode    1] total reward = -204.640762, length = 1031
# [Episode    2] total reward = -101.502663, length = 71
# [Episode    3] total reward = -120.150291, length = 102
# [Episode    4] total reward = -108.430710, length = 1600
# [Episode    5] total reward = -101.028984, length = 67
# [Episode    6] total reward = -130.418747, length = 128
# [Episode    7] total reward = -103.032234, length = 82
# [Episode    8] total reward = -102.464142, length = 66
# [Episode    9] total reward = -102.171600, length = 56
# [Episode   10] total reward = -98.492165, length = 90
# [Episode   11] total reward = -114.213806, length = 52
# [Episode   12] total reward = -103.883438, length = 58
# [Episode   13] total reward = -101.103027, length = 74
# [Episode   14] total reward = -103.736259, length = 82
# [Episode   15] total reward = -127.204727, length = 104
# [Episode   16] total reward = -100.017090, length = 86
# [Episode   17] total reward = -98.075729, length = 1600
# [Episode   18] total reward = -116.049957, length = 63
# [Episode   19] total reward = -102.040039, length = 55
# [Episode   20] total reward = -103.970665, length = 65
# [Episode   21] total reward = -118.728928, length = 73
# [Episode   22] total reward = -130.007690, length = 1600
# [Episode   23] total reward = -120.665970, length = 78
# [Episode   24] total reward = -70.563721, length = 1600
# [Episode   25] total reward = -104.417946, length = 94
# [Episode   26] total reward = -108.038849, length = 90
# [Episode   27] total reward = -118.689072, length = 1600
# [Episode   28] total reward = -107.435776, length = 131
# [Episode   29] total reward = -111.212204, length = 1600
# [Episode   30] total reward = -105.157082, length = 1600
# [Episode   31] total reward = -110.918816, length = 60
# [Episode   32] total reward = -100.334763, length = 76
# [Episode   33] total reward = -98.320419, length = 1600
# [Episode   34] total reward = -107.484306, length = 73
# [Episode   35] total reward = -106.958855, length = 56
# [Episode   36] total reward = -102.615204, length = 49
# [Episode   37] total reward = -104.832169, length = 1600
# [Episode   38] total reward = -105.074028, length = 55
# [Episode   39] total reward = -122.114395, length = 87
# [Episode   40] total reward = -106.187622, length = 126
# [Episode   41] total reward = -95.698654, length = 1600
# [Episode   42] total reward = -104.610420, length = 49
# [Episode   43] total reward = -86.589317, length = 1600
# [Episode   44] total reward = -109.197304, length = 110
# [Episode   45] total reward = -91.630692, length = 1600
# [Episode   46] total reward = -102.523346, length = 72
# [Episode   47] total reward = -93.599854, length = 1600
# [Episode   48] total reward = -85.137863, length = 1600
# [Episode   49] total reward = -106.901581, length = 111
# [Episode   50] total reward = -103.760559, length = 51
# [Episode   51] total reward = -74.147079, length = 1600
# [Episode   52] total reward = -123.376831, length = 93
# [Episode   53] total reward = -107.791161, length = 62
# [Episode   54] total reward = -84.299187, length = 1600
# [Episode   55] total reward = -70.583603, length = 1600
# [Episode   56] total reward = -79.263229, length = 1600
# [Episode   57] total reward = -109.245453, length = 135
# [Episode   58] total reward = -106.656456, length = 63
# [Episode   59] total reward = -100.783661, length = 74
# [Episode   60] total reward = -119.674614, length = 80
# [Episode   61] total reward = -78.993385, length = 1600
# [Episode   62] total reward = -117.883133, length = 63
# [Episode   63] total reward = -59.346287, length = 1600
# [Episode   64] total reward = -123.096497, length = 110
# [Episode   65] total reward = -111.456207, length = 63
# [Episode   66] total reward = -101.602936, length = 1600
# [Episode   67] total reward = -95.095154, length = 1600
# [Episode   68] total reward = -69.970322, length = 1600
# [Episode   69] total reward = -108.769875, length = 50
# [Episode   70] total reward = -75.636917, length = 1600
# [Episode   71] total reward = -113.179413, length = 69
# [Episode   72] total reward = -126.835289, length = 239
# [Episode   73] total reward = -62.372498, length = 1600
# [Episode   74] total reward = -115.588745, length = 66
# [Episode   75] total reward = -110.551552, length = 90
# [Episode   76] total reward = -107.424515, length = 78
# [Episode   77] total reward = -109.224991, length = 82
# [Episode   78] total reward = -117.790337, length = 69
# [Episode   79] total reward = -102.760033, length = 136
# [Episode   80] total reward = -66.697479, length = 1600
# [Episode   81] total reward = -112.731361, length = 65
# [Episode   82] total reward = -65.232109, length = 1600
# [Episode   83] total reward = -103.529808, length = 109
# [Episode   84] total reward = -117.380249, length = 271
# [Episode   85] total reward = -112.808754, length = 63
# [Episode   86] total reward = -112.908363, length = 79
# [Episode   87] total reward = -111.870422, length = 109
# [Episode   88] total reward = -115.602119, length = 71
# [Episode   89] total reward = -120.289444, length = 80
# [Episode   90] total reward = -109.039459, length = 73
# [Episode   91] total reward = -59.191170, length = 1600
# [Episode   92] total reward = -74.019608, length = 1600
# [Episode   93] total reward = -119.164230, length = 102
# [Episode   94] total reward = -63.517185, length = 1600
# [Episode   95] total reward = -108.799316, length = 65
# [Episode   96] total reward = -65.349854, length = 1600
# [Episode   97] total reward = -147.938797, length = 1126
# [Episode   98] total reward = -138.054092, length = 1082
# [Episode   99] total reward = -105.906296, length = 59
# [Episode  100] total reward = -102.797478, length = 69
# [Episode  101] total reward = -133.750671, length = 413
# [Episode  102] total reward = -69.041321, length = 1600
# [Episode  103] total reward = -108.373886, length = 55
# [Episode  104] total reward = -105.483025, length = 77
# [Episode  105] total reward = -111.506531, length = 61
# [Episode  106] total reward = -107.644699, length = 41
# [Episode  107] total reward = -115.384331, length = 167
# [Episode  108] total reward = -112.204254, length = 58
# [Episode  109] total reward = -71.138977, length = 1600
# [Episode  110] total reward = -100.912537, length = 118
# [Episode  111] total reward = -61.601234, length = 1600
# [Episode  112] total reward = -108.210655, length = 86
# [Episode  113] total reward = -71.187622, length = 1600
# [Episode  114] total reward = -111.215973, length = 109
# [Episode  115] total reward = -107.275223, length = 51
# [Episode  116] total reward = -106.420311, length = 63
# [Episode  117] total reward = -69.484802, length = 1600
# [Episode  118] total reward = -69.413338, length = 1600
# [Episode  119] total reward = -116.289688, length = 77
# [Episode  120] total reward = -123.114151, length = 148
# [Episode  121] total reward = -66.155075, length = 1600
# [Episode  122] total reward = -114.260864, length = 68
# [Episode  123] total reward = -147.809891, length = 1164
# [Episode  124] total reward = -108.269073, length = 81
# [Episode  125] total reward = -110.317223, length = 102
# [Episode  126] total reward = -74.524948, length = 1600
# [Episode  127] total reward = -70.086754, length = 1600
# [Episode  128] total reward = -103.670494, length = 69
# [Episode  129] total reward = -80.634605, length = 1600
# [Episode  130] total reward = -103.046135, length = 62
# [Episode  131] total reward = -68.679749, length = 1600
# [Episode  132] total reward = -102.670090, length = 56
# [Episode  133] total reward = -61.912735, length = 1600
# [Episode  134] total reward = -104.783005, length = 71
# [Episode  135] total reward = -102.202568, length = 110
# [Episode  136] total reward = -70.012337, length = 1600
# [Episode  137] total reward = -105.985863, length = 77
# [Episode  138] total reward = -113.630585, length = 97
# [Episode  139] total reward = -118.403748, length = 135
# [Episode  140] total reward = -112.530685, length = 59
# [Episode  141] total reward = -121.382858, length = 117
# [Episode  142] total reward = -72.713737, length = 1600
# [Episode  143] total reward = -116.390587, length = 62
# [Episode  144] total reward = -119.744888, length = 159
# [Episode  145] total reward = -122.191406, length = 86
# [Episode  146] total reward = -103.579643, length = 62
# [Episode  147] total reward = -103.267433, length = 86
# [Episode  148] total reward = -103.855446, length = 63
# [Episode  149] total reward = -103.529190, length = 100
# [Episode  150] total reward = -124.998032, length = 109
# [Episode  151] total reward = -124.304031, length = 136
# [Episode  152] total reward = -105.411942, length = 57
# [Episode  153] total reward = -103.995529, length = 85
# [Episode  154] total reward = -72.331009, length = 1600
# [Episode  155] total reward = -111.361496, length = 85
# [Episode  156] total reward = -175.711594, length = 1434
# [Episode  157] total reward = -106.238541, length = 99
# [Episode  158] total reward = -102.640579, length = 61
# [Episode  159] total reward = -83.874054, length = 1600
# [Episode  160] total reward = -108.120079, length = 90
# [Episode  161] total reward = -102.583771, length = 100
# [Episode  162] total reward = -114.359283, length = 74
# [Episode  163] total reward = -109.952133, length = 103
# [Episode  164] total reward = -70.154770, length = 1600
# [Episode  165] total reward = -73.969803, length = 1600
# [Episode  166] total reward = -112.695496, length = 60
# [Episode  167] total reward = -116.288918, length = 129
# [Episode  168] total reward = -105.480507, length = 117
# [Episode  169] total reward = -70.881409, length = 1600
# [Episode  170] total reward = -75.050766, length = 1600
# [Episode  171] total reward = -62.557510, length = 1600
# [Episode  172] total reward = -68.417343, length = 1600
# [Episode  173] total reward = -103.342278, length = 72
# [Episode  174] total reward = -107.895020, length = 63
# [Episode  175] total reward = -74.352753, length = 1600
# [Episode  176] total reward = -68.764633, length = 1600
# [Episode  177] total reward = -58.943356, length = 1600
# [Episode  178] total reward = -64.619827, length = 1600
# [Episode  179] total reward = -57.416649, length = 1600
# [Episode  180] total reward = -64.685883, length = 1600
# [Episode  181] total reward = -61.691704, length = 1600
# [Episode  182] total reward = -60.231880, length = 1600
# [Episode  183] total reward = -111.516418, length = 96
# [Episode  184] total reward = -116.799789, length = 81
# [Episode  185] total reward = -101.216591, length = 67
# [Episode  186] total reward = -63.589024, length = 1600
# [Episode  187] total reward = -45.366039, length = 1600
# [Episode  188] total reward = -129.897934, length = 106
# [Episode  189] total reward = -42.422504, length = 1600
# [Episode  190] total reward = -113.570076, length = 54
# [Episode  191] total reward = -113.962151, length = 96
# [Episode  192] total reward = -105.225014, length = 54
# [Episode  193] total reward = -113.926811, length = 42
# [Episode  194] total reward = -132.033264, length = 119
# [Episode  195] total reward = -100.924431, length = 117
# [Episode  196] total reward = -98.890533, length = 110
# [Episode  197] total reward = -109.017509, length = 115
# [Episode  198] total reward = -105.635170, length = 78
# [Episode  199] total reward = -116.767128, length = 98
# [Episode  200] total reward = -132.993408, length = 791
#
# [  200 /  5000]
# ----------------------------------
# actor loss = -0.076554
# critic loss = 568.102295
# entropy = 5.663224
# mean return = -100.806163
# mean length = 602.63
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -102.712441, length = 113
#  99%|█████████▉| 114/115 [00:00<00:00, 257.48it/s]
# [Episode  201] total reward = -118.356674, length = 64
# [Episode  202] total reward = -111.698143, length = 62
# [Episode  203] total reward = -103.272301, length = 56
# [Episode  204] total reward = -108.632858, length = 55
# [Episode  205] total reward = -99.083115, length = 110
# [Episode  206] total reward = -109.133118, length = 51
# [Episode  207] total reward = -112.712479, length = 85
# [Episode  208] total reward = -117.089157, length = 159
# [Episode  209] total reward = -142.641113, length = 1066
# [Episode  210] total reward = -50.648354, length = 1600
# [Episode  211] total reward = -106.942024, length = 71
# [Episode  212] total reward = -64.845367, length = 1600
# [Episode  213] total reward = -106.015991, length = 52
# [Episode  214] total reward = -114.473694, length = 146
# [Episode  215] total reward = -108.575813, length = 87
# [Episode  216] total reward = -112.226074, length = 82
# [Episode  217] total reward = -53.641434, length = 1600
# [Episode  218] total reward = -161.816711, length = 1366
# [Episode  219] total reward = -116.548187, length = 83
# [Episode  220] total reward = -62.091419, length = 1600
# [Episode  221] total reward = -109.853043, length = 71
# [Episode  222] total reward = -67.350845, length = 1600
# [Episode  223] total reward = -122.848984, length = 84
# [Episode  224] total reward = -76.943771, length = 1600
# [Episode  225] total reward = -110.996841, length = 83
# [Episode  226] total reward = -68.001556, length = 1600
# [Episode  227] total reward = -61.531578, length = 1600
# [Episode  228] total reward = -49.502556, length = 1600
# [Episode  229] total reward = -105.742958, length = 50
# [Episode  230] total reward = -70.022110, length = 1600
# [Episode  231] total reward = -110.559425, length = 90
# [Episode  232] total reward = -115.730682, length = 123
# [Episode  233] total reward = -100.924362, length = 68
# [Episode  234] total reward = -103.681122, length = 59
# [Episode  235] total reward = -68.189789, length = 1600
# [Episode  236] total reward = -51.534561, length = 1600
# [Episode  237] total reward = -104.946007, length = 83
# [Episode  238] total reward = -105.006233, length = 81
# [Episode  239] total reward = -106.340996, length = 66
# [Episode  240] total reward = -104.145073, length = 68
# [Episode  241] total reward = -105.898750, length = 122
# [Episode  242] total reward = -102.245728, length = 56
# [Episode  243] total reward = -109.506989, length = 95
# [Episode  244] total reward = -108.874924, length = 155
# [Episode  245] total reward = -59.915215, length = 1600
# [Episode  246] total reward = -128.712173, length = 169
# [Episode  247] total reward = -65.807877, length = 1600
# [Episode  248] total reward = -62.938042, length = 1600
# [Episode  249] total reward = -108.953575, length = 88
# [Episode  250] total reward = -104.264763, length = 150
# [Episode  251] total reward = -73.692932, length = 1600
# [Episode  252] total reward = -57.674553, length = 1600
# [Episode  253] total reward = -64.453094, length = 1600
# [Episode  254] total reward = -59.103214, length = 1600
# [Episode  255] total reward = -51.910278, length = 1600
# [Episode  256] total reward = -41.444149, length = 1600
# [Episode  257] total reward = -68.349373, length = 1600
# [Episode  258] total reward = -38.698292, length = 1600
# [Episode  259] total reward = -100.684486, length = 60
# [Episode  260] total reward = -55.723507, length = 1600
# [Episode  261] total reward = -115.279106, length = 59
# [Episode  262] total reward = -110.536217, length = 60
# [Episode  263] total reward = -102.567589, length = 75
# [Episode  264] total reward = -42.900265, length = 1600
# [Episode  265] total reward = -132.895767, length = 906
# [Episode  266] total reward = -116.173424, length = 65
# [Episode  267] total reward = -44.067734, length = 1600
# [Episode  268] total reward = -111.722229, length = 46
# [Episode  269] total reward = -40.374443, length = 1600
# [Episode  270] total reward = -116.131668, length = 101
# [Episode  271] total reward = -106.125748, length = 58
# [Episode  272] total reward = -108.594650, length = 89
# [Episode  273] total reward = -18.709354, length = 1600
# [Episode  274] total reward = -123.902100, length = 114
# [Episode  275] total reward = -115.451088, length = 57
# [Episode  276] total reward = -31.327131, length = 1600
# [Episode  277] total reward = -115.527168, length = 59
# [Episode  278] total reward = -12.090106, length = 1600
# [Episode  279] total reward = -14.802482, length = 1600
# [Episode  280] total reward = -110.206367, length = 599
# [Episode  281] total reward = -110.936981, length = 76
# [Episode  282] total reward = -120.362167, length = 87
# [Episode  283] total reward = -112.855873, length = 70
# [Episode  284] total reward = -125.627449, length = 96
# [Episode  285] total reward = -106.770149, length = 355
# [Episode  286] total reward = -124.782776, length = 117
# [Episode  287] total reward = -5.242034, length = 1600
# [Episode  288] total reward = -115.246925, length = 106
# [Episode  289] total reward = -115.188225, length = 132
# [Episode  290] total reward = -115.064316, length = 50
# [Episode  291] total reward = -17.661665, length = 1600
# [Episode  292] total reward = -113.004829, length = 75
# [Episode  293] total reward = -114.842834, length = 923
# [Episode  294] total reward = -6.614564, length = 1600
# [Episode  295] total reward = -26.456200, length = 1600
# [Episode  296] total reward = -17.346958, length = 1600
# [Episode  297] total reward = -98.393745, length = 1032
# [Episode  298] total reward = -97.331108, length = 1077
# [Episode  299] total reward = -118.946808, length = 100
# [Episode  300] total reward = -117.548119, length = 57
# [Episode  301] total reward = -137.074631, length = 112
# [Episode  302] total reward = -114.901497, length = 91
# [Episode  303] total reward = -109.422119, length = 1525
# [Episode  304] total reward = -112.312790, length = 610
# [Episode  305] total reward = -115.696548, length = 65
# [Episode  306] total reward = -114.303650, length = 48
# [Episode  307] total reward = -107.962791, length = 1043
# [Episode  308] total reward = -116.212280, length = 63
# [Episode  309] total reward = -105.858421, length = 483
# [Episode  310] total reward = -120.766899, length = 961
# [Episode  311] total reward = -119.051140, length = 101
# [Episode  312] total reward = -98.213860, length = 855
# [Episode  313] total reward = 6.828426, length = 1600
# [Episode  314] total reward = -15.248545, length = 1600
# [Episode  315] total reward = -106.178581, length = 85
# [Episode  316] total reward = -7.966595, length = 1600
# [Episode  317] total reward = -110.917603, length = 884
# [Episode  318] total reward = -123.556877, length = 88
# [Episode  319] total reward = -113.337662, length = 64
# [Episode  320] total reward = -125.045235, length = 98
# [Episode  321] total reward = -122.215973, length = 636
# [Episode  322] total reward = -108.600128, length = 55
# [Episode  323] total reward = -24.272364, length = 1600
# [Episode  324] total reward = -38.163422, length = 1600
# [Episode  325] total reward = -112.154274, length = 68
# [Episode  326] total reward = -31.099506, length = 1600
# [Episode  327] total reward = -22.186325, length = 1600
# [Episode  328] total reward = -116.805565, length = 67
# [Episode  329] total reward = -27.748318, length = 1600
# [Episode  330] total reward = -13.302303, length = 1600
# [Episode  331] total reward = -108.163193, length = 89
# [Episode  332] total reward = -21.661583, length = 1600
# [Episode  333] total reward = -21.311115, length = 1600
# [Episode  334] total reward = -118.442581, length = 75
# [Episode  335] total reward = -120.356079, length = 82
# [Episode  336] total reward = -9.021861, length = 1600
# [Episode  337] total reward = -128.948349, length = 117
# [Episode  338] total reward = -3.309260, length = 1600
# [Episode  339] total reward = -15.318914, length = 1600
# [Episode  340] total reward = -122.897354, length = 114
# [Episode  341] total reward = -120.525108, length = 64
# [Episode  342] total reward = -111.256058, length = 94
# [Episode  343] total reward = -20.614048, length = 1600
# [Episode  344] total reward = -2.502383, length = 1600
# [Episode  345] total reward = -4.144955, length = 1600
# [Episode  346] total reward = -119.251404, length = 51
# [Episode  347] total reward = -9.937569, length = 1600
# [Episode  348] total reward = 18.026108, length = 1600
# [Episode  349] total reward = 24.922255, length = 1600
# [Episode  350] total reward = -114.954422, length = 581
# [Episode  351] total reward = -110.329529, length = 97
# [Episode  352] total reward = 43.292480, length = 1600
# [Episode  353] total reward = 13.179253, length = 1600
# [Episode  354] total reward = 46.088196, length = 1600
# [Episode  355] total reward = 32.618618, length = 1600
# [Episode  356] total reward = -62.839695, length = 1107
# [Episode  357] total reward = -110.358177, length = 47
# [Episode  358] total reward = -120.059998, length = 55
# [Episode  359] total reward = 43.234238, length = 1600
# [Episode  360] total reward = -121.162384, length = 110
# [Episode  361] total reward = -116.192558, length = 51
# [Episode  362] total reward = -99.132820, length = 178
# [Episode  363] total reward = -52.940456, length = 1571
# [Episode  364] total reward = -99.143730, length = 117
# [Episode  365] total reward = -119.288528, length = 91
# [Episode  366] total reward = -112.124870, length = 150
# [Episode  367] total reward = -107.711159, length = 223
# [Episode  368] total reward = -106.689896, length = 90
# [Episode  369] total reward = -114.547272, length = 83
# [Episode  370] total reward = -94.593925, length = 251
# [Episode  371] total reward = -118.035126, length = 58
# [Episode  372] total reward = -87.939621, length = 537
# [Episode  373] total reward = -123.325134, length = 136
# [Episode  374] total reward = -108.603996, length = 40
# [Episode  375] total reward = -114.166008, length = 60
# [Episode  376] total reward = -107.790459, length = 152
# [Episode  377] total reward = -110.811378, length = 71
# [Episode  378] total reward = -115.409882, length = 53
# [Episode  379] total reward = -111.265045, length = 86
# [Episode  380] total reward = -108.013077, length = 65
# [Episode  381] total reward = -117.163452, length = 168
# [Episode  382] total reward = -118.814102, length = 90
# [Episode  383] total reward = -110.316444, length = 69
# [Episode  384] total reward = -106.813034, length = 449
# [Episode  385] total reward = -115.517136, length = 77
# [Episode  386] total reward = -119.994484, length = 85
# [Episode  387] total reward = -115.393295, length = 58
# [Episode  388] total reward = -108.146835, length = 49
# [Episode  389] total reward = -115.741638, length = 65
# [Episode  390] total reward = -84.936432, length = 691
# [Episode  391] total reward = -113.726654, length = 44
# [Episode  392] total reward = 47.422806, length = 1600
# [Episode  393] total reward = -90.449211, length = 517
# [Episode  394] total reward = -113.137306, length = 65
# [Episode  395] total reward = -94.719345, length = 490
# [Episode  396] total reward = -118.626518, length = 62
# [Episode  397] total reward = -116.544693, length = 98
# [Episode  398] total reward = 54.134392, length = 1600
# [Episode  399] total reward = 33.545509, length = 1600
# [Episode  400] total reward = -116.744476, length = 54
#
# [  400 /  5000]
# ----------------------------------
# actor loss = -0.062908
# critic loss = 7805.824219
# entropy = 5.599960
# mean return = -84.309582
# mean length = 661.68
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -112.265485, length = 64
# 100%|██████████| 66/66 [00:00<00:00, 261.47it/s]
# [Episode  401] total reward = -92.752304, length = 1307
# [Episode  402] total reward = 29.778091, length = 1600
# [Episode  403] total reward = 22.646507, length = 1600
# [Episode  404] total reward = -108.195946, length = 62
# [Episode  405] total reward = 48.109631, length = 1600
# [Episode  406] total reward = -112.816071, length = 65
# [Episode  407] total reward = -117.251099, length = 130
# [Episode  408] total reward = -113.757683, length = 169
# [Episode  409] total reward = 47.462372, length = 1600
# [Episode  410] total reward = -111.650078, length = 72
# [Episode  411] total reward = -99.704239, length = 1072
# [Episode  412] total reward = 44.181351, length = 1600
# [Episode  413] total reward = -100.746193, length = 259
# [Episode  414] total reward = -120.212860, length = 117
# [Episode  415] total reward = -109.695839, length = 253
# [Episode  416] total reward = 30.500816, length = 1600
# [Episode  417] total reward = -104.799248, length = 74
# [Episode  418] total reward = -115.067375, length = 62
# [Episode  419] total reward = -116.889732, length = 65
# [Episode  420] total reward = 45.894527, length = 1600
# [Episode  421] total reward = 27.859770, length = 1600
# [Episode  422] total reward = -111.756294, length = 59
# [Episode  423] total reward = -122.455917, length = 81
# [Episode  424] total reward = 36.904037, length = 1600
# [Episode  425] total reward = 31.161026, length = 1600
# [Episode  426] total reward = -111.757759, length = 60
# [Episode  427] total reward = -107.058464, length = 60
# [Episode  428] total reward = 18.439690, length = 1600
# [Episode  429] total reward = -102.674545, length = 60
# [Episode  430] total reward = -125.253105, length = 132
# [Episode  431] total reward = -76.548370, length = 1039
# [Episode  432] total reward = -107.123177, length = 79
# [Episode  433] total reward = -116.318848, length = 70
# [Episode  434] total reward = -70.128197, length = 1531
# [Episode  435] total reward = -115.700478, length = 901
# [Episode  436] total reward = 33.251659, length = 1600
# [Episode  437] total reward = 9.547134, length = 1600
# [Episode  438] total reward = -109.747467, length = 54
# [Episode  439] total reward = -118.374039, length = 85
# [Episode  440] total reward = -74.271423, length = 1191
# [Episode  441] total reward = -127.733391, length = 979
# [Episode  442] total reward = -115.881363, length = 105
# [Episode  443] total reward = 10.843810, length = 1600
# [Episode  444] total reward = -104.647987, length = 667
# [Episode  445] total reward = -113.102219, length = 61
# [Episode  446] total reward = 20.632092, length = 1600
# [Episode  447] total reward = -106.859032, length = 945
# [Episode  448] total reward = -118.016380, length = 95
# [Episode  449] total reward = -102.496162, length = 52
# [Episode  450] total reward = -99.532242, length = 1519
# [Episode  451] total reward = -109.349846, length = 46
# [Episode  452] total reward = -116.031067, length = 82
# [Episode  453] total reward = -111.279572, length = 60
# [Episode  454] total reward = -115.660202, length = 61
# [Episode  455] total reward = -104.724396, length = 58
# [Episode  456] total reward = 10.464185, length = 1600
# [Episode  457] total reward = 8.810069, length = 1600
# [Episode  458] total reward = 19.286644, length = 1600
# [Episode  459] total reward = -116.210464, length = 55
# [Episode  460] total reward = -2.617842, length = 1600
# [Episode  461] total reward = -104.301941, length = 59
# [Episode  462] total reward = -105.847893, length = 77
# [Episode  463] total reward = 10.879009, length = 1600
# [Episode  464] total reward = -107.651047, length = 1204
# [Episode  465] total reward = 20.763979, length = 1600
# [Episode  466] total reward = -109.421387, length = 49
# [Episode  467] total reward = 38.291031, length = 1600
# [Episode  468] total reward = -107.476883, length = 79
# [Episode  469] total reward = -113.157120, length = 61
# [Episode  470] total reward = -116.627937, length = 82
# [Episode  471] total reward = -109.783920, length = 56
# [Episode  472] total reward = -98.579376, length = 617
# [Episode  473] total reward = -114.095451, length = 53
# [Episode  474] total reward = 36.852318, length = 1600
# [Episode  475] total reward = 10.781619, length = 1600
# [Episode  476] total reward = -109.681541, length = 68
# [Episode  477] total reward = -95.197578, length = 332
# [Episode  478] total reward = -109.398659, length = 60
# [Episode  479] total reward = -98.897736, length = 1007
# [Episode  480] total reward = -88.614243, length = 532
# [Episode  481] total reward = -111.372849, length = 275
# [Episode  482] total reward = -101.272881, length = 65
# [Episode  483] total reward = -105.478508, length = 61
# [Episode  484] total reward = 50.236389, length = 1600
# [Episode  485] total reward = -109.413292, length = 72
# [Episode  486] total reward = -112.033134, length = 68
# [Episode  487] total reward = -77.839195, length = 1103
# [Episode  488] total reward = 26.158596, length = 1600
# [Episode  489] total reward = 37.936890, length = 1600
# [Episode  490] total reward = 34.136322, length = 1600
# [Episode  491] total reward = -110.311432, length = 68
# [Episode  492] total reward = -117.104141, length = 63
# [Episode  493] total reward = 21.348175, length = 1600
# [Episode  494] total reward = -113.847427, length = 52
# [Episode  495] total reward = -110.062332, length = 69
# [Episode  496] total reward = -100.292854, length = 69
# [Episode  497] total reward = 35.115376, length = 1600
# [Episode  498] total reward = -103.520287, length = 55
# [Episode  499] total reward = -116.439766, length = 60
# [Episode  500] total reward = 34.331314, length = 1600
# [Episode  501] total reward = -103.201118, length = 46
# [Episode  502] total reward = -116.313324, length = 79
# [Episode  503] total reward = -106.082649, length = 1132
# [Episode  504] total reward = -106.472588, length = 62
# [Episode  505] total reward = -106.719009, length = 45
# [Episode  506] total reward = 23.767958, length = 1600
# [Episode  507] total reward = -107.881889, length = 84
# [Episode  508] total reward = -115.295174, length = 58
# [Episode  509] total reward = -124.699036, length = 70
# [Episode  510] total reward = -102.675758, length = 60
# [Episode  511] total reward = -118.432495, length = 65
# [Episode  512] total reward = -108.246513, length = 65
# [Episode  513] total reward = -101.593353, length = 124
# [Episode  514] total reward = -93.692146, length = 774
# [Episode  515] total reward = -107.488472, length = 48
# [Episode  516] total reward = -124.415581, length = 89
# [Episode  517] total reward = 67.745155, length = 1600
# [Episode  518] total reward = 53.658413, length = 1600
# [Episode  519] total reward = -104.997017, length = 55
# [Episode  520] total reward = -100.261047, length = 71
# [Episode  521] total reward = -102.713135, length = 83
# [Episode  522] total reward = -101.476372, length = 51
# [Episode  523] total reward = -110.058578, length = 77
# [Episode  524] total reward = -101.932892, length = 48
# [Episode  525] total reward = -103.787788, length = 46
# [Episode  526] total reward = -101.783775, length = 81
# [Episode  527] total reward = -101.608208, length = 53
# [Episode  528] total reward = -101.575302, length = 61
# [Episode  529] total reward = -103.855949, length = 46
# [Episode  530] total reward = 4.086750, length = 1600
# [Episode  531] total reward = -99.620712, length = 85
# [Episode  532] total reward = -111.522964, length = 75
# [Episode  533] total reward = -98.436226, length = 81
# [Episode  534] total reward = -103.128792, length = 66
# [Episode  535] total reward = 24.042446, length = 1600
# [Episode  536] total reward = -97.840172, length = 147
# [Episode  537] total reward = -107.997627, length = 48
# [Episode  538] total reward = -115.548836, length = 72
# [Episode  539] total reward = 16.273895, length = 1600
# [Episode  540] total reward = -110.037285, length = 69
# [Episode  541] total reward = -102.829170, length = 55
# [Episode  542] total reward = -0.168107, length = 1600
# [Episode  543] total reward = -2.354235, length = 1600
# [Episode  544] total reward = -118.003082, length = 55
# [Episode  545] total reward = -107.683548, length = 68
# [Episode  546] total reward = 11.949524, length = 1600
# [Episode  547] total reward = -12.054678, length = 1600
# [Episode  548] total reward = -106.392426, length = 46
# [Episode  549] total reward = -2.598001, length = 1600
# [Episode  550] total reward = 12.294953, length = 1600
# [Episode  551] total reward = 12.705018, length = 1600
# [Episode  552] total reward = 3.396390, length = 1600
# [Episode  553] total reward = -104.216919, length = 51
# [Episode  554] total reward = -103.654091, length = 66
# [Episode  555] total reward = 25.436855, length = 1600
# [Episode  556] total reward = -106.480347, length = 71
# [Episode  557] total reward = -111.631721, length = 94
# [Episode  558] total reward = 12.109666, length = 1600
# [Episode  559] total reward = -102.392349, length = 51
# [Episode  560] total reward = -109.542267, length = 61
# [Episode  561] total reward = 11.355159, length = 1600
# [Episode  562] total reward = -101.851860, length = 49
# [Episode  563] total reward = -99.630318, length = 64
# [Episode  564] total reward = -103.229126, length = 48
# [Episode  565] total reward = -101.778091, length = 47
# [Episode  566] total reward = -103.666870, length = 50
# [Episode  567] total reward = -100.322632, length = 62
# [Episode  568] total reward = -121.471260, length = 81
# [Episode  569] total reward = -105.083397, length = 43
# [Episode  570] total reward = 20.681538, length = 1600
# [Episode  571] total reward = 0.020196, length = 1600
# [Episode  572] total reward = 21.837166, length = 1600
# [Episode  573] total reward = 1.425368, length = 1600
# [Episode  574] total reward = -102.893631, length = 50
# [Episode  575] total reward = -100.069000, length = 69
# [Episode  576] total reward = -111.693787, length = 71
# [Episode  577] total reward = -104.014496, length = 52
# [Episode  578] total reward = -101.864204, length = 72
# [Episode  579] total reward = -0.001711, length = 1600
# [Episode  580] total reward = 36.100822, length = 1600
# [Episode  581] total reward = -99.833931, length = 77
# [Episode  582] total reward = -99.776817, length = 52
# [Episode  583] total reward = -107.895401, length = 51
# [Episode  584] total reward = 20.159485, length = 1600
# [Episode  585] total reward = 10.108941, length = 1600
# [Episode  586] total reward = 28.209249, length = 1600
# [Episode  587] total reward = -103.932556, length = 67
# [Episode  588] total reward = 12.243666, length = 1600
# [Episode  589] total reward = 26.099941, length = 1600
# [Episode  590] total reward = -100.787384, length = 71
# [Episode  591] total reward = -102.265404, length = 60
# [Episode  592] total reward = 29.713020, length = 1600
# [Episode  593] total reward = -109.703659, length = 52
# [Episode  594] total reward = -108.566307, length = 69
# [Episode  595] total reward = -105.821663, length = 45
# [Episode  596] total reward = -104.159782, length = 52
# [Episode  597] total reward = 7.358971, length = 1600
# [Episode  598] total reward = 30.778505, length = 1600
# [Episode  599] total reward = 37.982834, length = 1600
# [Episode  600] total reward = 40.068924, length = 1600
#
# [  600 /  5000]
# ----------------------------------
# actor loss = -0.153987
# critic loss = 17.747246
# entropy = 5.615212
# mean return = -65.460302
# mean length = 643.99
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -105.168754, length = 55
# 100%|██████████| 57/57 [00:00<00:00, 255.30it/s]
# [Episode  601] total reward = -106.942047, length = 62
# [Episode  602] total reward = -113.596550, length = 65
# [Episode  603] total reward = 48.217804, length = 1600
# [Episode  604] total reward = 31.726194, length = 1600
# [Episode  605] total reward = 36.221970, length = 1600
# [Episode  606] total reward = -103.567345, length = 47
# [Episode  607] total reward = 51.874870, length = 1600
# [Episode  608] total reward = -105.215332, length = 56
# [Episode  609] total reward = -104.930511, length = 98
# [Episode  610] total reward = 46.044601, length = 1600
# [Episode  611] total reward = -119.660637, length = 135
# [Episode  612] total reward = -106.170525, length = 68
# [Episode  613] total reward = -101.315300, length = 102
# [Episode  614] total reward = 44.282074, length = 1600
# [Episode  615] total reward = -103.173439, length = 60
# [Episode  616] total reward = -101.417091, length = 57
# [Episode  617] total reward = 63.056152, length = 1600
# [Episode  618] total reward = -107.198380, length = 60
# [Episode  619] total reward = -107.616234, length = 505
# [Episode  620] total reward = 52.386715, length = 1600
# [Episode  621] total reward = -100.877480, length = 51
# [Episode  622] total reward = 56.894035, length = 1600
# [Episode  623] total reward = 58.988415, length = 1600
# [Episode  624] total reward = -103.056229, length = 58
# [Episode  625] total reward = 61.582500, length = 1600
# [Episode  626] total reward = -108.480667, length = 116
# [Episode  627] total reward = -118.856552, length = 197
# [Episode  628] total reward = -129.915314, length = 114
# [Episode  629] total reward = -104.258583, length = 44
# [Episode  630] total reward = 44.898167, length = 1600
# [Episode  631] total reward = -106.969986, length = 39
# [Episode  632] total reward = 44.088196, length = 1600
# [Episode  633] total reward = -106.257820, length = 53
# [Episode  634] total reward = -96.035156, length = 110
# [Episode  635] total reward = -102.663147, length = 39
# [Episode  636] total reward = -106.892258, length = 44
# [Episode  637] total reward = 49.418358, length = 1600
# [Episode  638] total reward = 47.399445, length = 1600
# [Episode  639] total reward = -119.055191, length = 80
# [Episode  640] total reward = 53.196594, length = 1600
# [Episode  641] total reward = 71.721481, length = 1600
# [Episode  642] total reward = 85.792839, length = 1600
# [Episode  643] total reward = -105.521210, length = 47
# [Episode  644] total reward = -109.345009, length = 51
# [Episode  645] total reward = -108.803123, length = 65
# [Episode  646] total reward = -113.261353, length = 76
# [Episode  647] total reward = 58.198814, length = 1600
# [Episode  648] total reward = -78.923492, length = 1004
# [Episode  649] total reward = 45.660835, length = 1600
# [Episode  650] total reward = -108.789398, length = 41
# [Episode  651] total reward = 60.229145, length = 1600
# [Episode  652] total reward = 55.895573, length = 1600
# [Episode  653] total reward = -107.432884, length = 49
# [Episode  654] total reward = 54.180305, length = 1600
# [Episode  655] total reward = -118.225060, length = 110
# [Episode  656] total reward = 61.475655, length = 1600
# [Episode  657] total reward = 63.980785, length = 1600
# [Episode  658] total reward = -87.479828, length = 1361
# [Episode  659] total reward = -110.866226, length = 46
# [Episode  660] total reward = 35.366467, length = 1600
# [Episode  661] total reward = 50.340927, length = 1600
# [Episode  662] total reward = 62.943508, length = 1600
# [Episode  663] total reward = 74.499298, length = 1600
# [Episode  664] total reward = 67.314301, length = 1600
# [Episode  665] total reward = -113.828888, length = 79
# [Episode  666] total reward = -118.664139, length = 48
# [Episode  667] total reward = 60.077446, length = 1600
# [Episode  668] total reward = -115.483124, length = 65
# [Episode  669] total reward = 47.889854, length = 1600
# [Episode  670] total reward = 39.247818, length = 1600
# [Episode  671] total reward = 70.370193, length = 1600
# [Episode  672] total reward = 24.137009, length = 1600
# [Episode  673] total reward = 65.489319, length = 1600
# [Episode  674] total reward = 73.099007, length = 1600
# [Episode  675] total reward = 76.151093, length = 1600
# [Episode  676] total reward = 67.869995, length = 1600
# [Episode  677] total reward = 60.930557, length = 1600
# [Episode  678] total reward = 70.060944, length = 1600
# [Episode  679] total reward = 50.394051, length = 1600
# [Episode  680] total reward = 69.846100, length = 1600
# [Episode  681] total reward = 92.740601, length = 1600
# [Episode  682] total reward = 73.666328, length = 1600
# [Episode  683] total reward = 78.207092, length = 1600
# [Episode  684] total reward = 107.626663, length = 1600
# [Episode  685] total reward = 86.481247, length = 1600
# [Episode  686] total reward = 90.619949, length = 1600
# [Episode  687] total reward = -114.310104, length = 53
# [Episode  688] total reward = 103.342392, length = 1600
# [Episode  689] total reward = -112.715256, length = 56
# [Episode  690] total reward = 96.254227, length = 1600
# [Episode  691] total reward = -116.424683, length = 67
# [Episode  692] total reward = -113.177811, length = 52
# [Episode  693] total reward = -41.679588, length = 1430
# [Episode  694] total reward = -96.085114, length = 398
# [Episode  695] total reward = 98.314751, length = 1600
# [Episode  696] total reward = 112.605019, length = 1600
# [Episode  697] total reward = 104.541962, length = 1600
# [Episode  698] total reward = 94.793488, length = 1600
# [Episode  699] total reward = 123.489746, length = 1600
# [Episode  700] total reward = 100.122643, length = 1600
# [Episode  701] total reward = -109.620079, length = 47
# [Episode  702] total reward = -120.029945, length = 88
# [Episode  703] total reward = -111.374207, length = 118
# [Episode  704] total reward = 143.565384, length = 1600
# [Episode  705] total reward = 140.571442, length = 1600
# [Episode  706] total reward = -118.773499, length = 51
# [Episode  707] total reward = -45.196289, length = 1166
# [Episode  708] total reward = 103.662216, length = 1600
# [Episode  709] total reward = 129.782959, length = 1600
# [Episode  710] total reward = 148.657806, length = 1600
# [Episode  711] total reward = 152.654251, length = 1600
# [Episode  712] total reward = -114.818794, length = 109
# [Episode  713] total reward = -113.789856, length = 105
# [Episode  714] total reward = -113.340042, length = 74
# [Episode  715] total reward = -86.548660, length = 287
# [Episode  716] total reward = 119.637482, length = 1600
# [Episode  717] total reward = -105.974960, length = 46
# [Episode  718] total reward = -113.512001, length = 64
# [Episode  719] total reward = 117.881027, length = 1600
# [Episode  720] total reward = 134.180588, length = 1600
# [Episode  721] total reward = -121.472672, length = 50
# [Episode  722] total reward = 122.355049, length = 1600
# [Episode  723] total reward = -84.657471, length = 340
# [Episode  724] total reward = -115.487923, length = 50
# [Episode  725] total reward = -35.929512, length = 1092
# [Episode  726] total reward = -109.930641, length = 109
# [Episode  727] total reward = 126.301987, length = 1600
# [Episode  728] total reward = -29.168922, length = 1170
# [Episode  729] total reward = 22.930302, length = 1592
# [Episode  730] total reward = 105.013046, length = 1600
# [Episode  731] total reward = 120.686562, length = 1600
# [Episode  732] total reward = -37.457012, length = 918
# [Episode  733] total reward = -101.981430, length = 479
# [Episode  734] total reward = -119.130646, length = 49
# [Episode  735] total reward = -114.928154, length = 72
# [Episode  736] total reward = -115.032990, length = 58
# [Episode  737] total reward = -119.100288, length = 88
# [Episode  738] total reward = -113.577072, length = 60
# [Episode  739] total reward = -104.254303, length = 124
# [Episode  740] total reward = -111.945496, length = 62
# [Episode  741] total reward = 99.533333, length = 1600
# [Episode  742] total reward = -47.267876, length = 884
# [Episode  743] total reward = -120.119247, length = 52
# [Episode  744] total reward = -120.269791, length = 70
# [Episode  745] total reward = -111.157784, length = 50
# [Episode  746] total reward = -124.688202, length = 62
# [Episode  747] total reward = 141.041809, length = 1600
# [Episode  748] total reward = -118.911484, length = 54
# [Episode  749] total reward = -64.096359, length = 631
# [Episode  750] total reward = -111.035812, length = 66
# [Episode  751] total reward = -117.484634, length = 51
# [Episode  752] total reward = 143.169907, length = 1600
# [Episode  753] total reward = 115.855057, length = 1600
# [Episode  754] total reward = -122.934189, length = 53
# [Episode  755] total reward = 130.703186, length = 1600
# [Episode  756] total reward = -8.825756, length = 1165
# [Episode  757] total reward = -116.472321, length = 85
# [Episode  758] total reward = 171.664978, length = 1600
# [Episode  759] total reward = 137.432663, length = 1600
# [Episode  760] total reward = 138.624634, length = 1600
# [Episode  761] total reward = -113.743568, length = 151
# [Episode  762] total reward = 30.593296, length = 1555
# [Episode  763] total reward = 154.538086, length = 1600
# [Episode  764] total reward = 147.805878, length = 1600
# [Episode  765] total reward = 163.773682, length = 1600
# [Episode  766] total reward = 10.835857, length = 1197
# [Episode  767] total reward = -28.238346, length = 901
# [Episode  768] total reward = -111.824059, length = 62
# [Episode  769] total reward = -11.703033, length = 1141
# [Episode  770] total reward = -120.618561, length = 72
# [Episode  771] total reward = 166.009918, length = 1600
# [Episode  772] total reward = -63.098385, length = 718
# [Episode  773] total reward = 157.551300, length = 1600
# [Episode  774] total reward = -120.352859, length = 51
# [Episode  775] total reward = -114.965866, length = 57
# [Episode  776] total reward = -112.195816, length = 136
# [Episode  777] total reward = -85.020004, length = 230
# [Episode  778] total reward = -76.533699, length = 352
# [Episode  779] total reward = -30.469231, length = 627
# [Episode  780] total reward = -119.290344, length = 124
# [Episode  781] total reward = -121.987038, length = 53
# [Episode  782] total reward = -99.840126, length = 211
# [Episode  783] total reward = -112.789162, length = 52
# [Episode  784] total reward = -53.585728, length = 569
# [Episode  785] total reward = -109.812965, length = 110
# [Episode  786] total reward = -113.746765, length = 48
# [Episode  787] total reward = -104.372498, length = 143
# [Episode  788] total reward = 181.725861, length = 1600
# [Episode  789] total reward = -21.307728, length = 756
# [Episode  790] total reward = 183.324356, length = 1600
# [Episode  791] total reward = -99.099327, length = 355
# [Episode  792] total reward = -29.475964, length = 772
# [Episode  793] total reward = 152.120789, length = 1600
# [Episode  794] total reward = -116.668541, length = 484
# [Episode  795] total reward = -105.489296, length = 46
# [Episode  796] total reward = -109.831329, length = 64
# [Episode  797] total reward = 173.300735, length = 1600
# [Episode  798] total reward = 174.839722, length = 1600
# [Episode  799] total reward = -108.448196, length = 59
# [Episode  800] total reward = 168.990295, length = 1600
#
# [  800 /  5000]
# ----------------------------------
# actor loss = -0.003522
# critic loss = 46.134769
# entropy = 5.585449
# mean return = -11.761909
# mean length = 862.73
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 250.838809, length = 1392
# 100%|██████████| 1393/1393 [00:05<00:00, 277.24it/s]
# [Episode  801] total reward = -38.348915, length = 934
# [Episode  802] total reward = 164.327271, length = 1600
# [Episode  803] total reward = -118.799713, length = 53
# [Episode  804] total reward = 162.401855, length = 1600
# [Episode  805] total reward = 162.635773, length = 1600
# [Episode  806] total reward = 167.462616, length = 1600
# [Episode  807] total reward = -113.312698, length = 59
# [Episode  808] total reward = -114.363510, length = 76
# [Episode  809] total reward = -66.343414, length = 486
# [Episode  810] total reward = 144.157288, length = 1600
# [Episode  811] total reward = 6.874947, length = 768
# [Episode  812] total reward = -108.886757, length = 58
# [Episode  813] total reward = 209.877441, length = 1600
# [Episode  814] total reward = 169.432556, length = 1600
# [Episode  815] total reward = 187.779144, length = 1600
# [Episode  816] total reward = -107.334686, length = 46
# [Episode  817] total reward = 180.037262, length = 1600
# [Episode  818] total reward = -36.932457, length = 676
# [Episode  819] total reward = -17.393696, length = 699
# [Episode  820] total reward = -112.309052, length = 71
# [Episode  821] total reward = -102.588120, length = 92
# [Episode  822] total reward = 183.128601, length = 1600
# [Episode  823] total reward = -116.712540, length = 77
# [Episode  824] total reward = -116.121811, length = 59
# [Episode  825] total reward = -122.172546, length = 166
# [Episode  826] total reward = 226.395645, length = 1590
# [Episode  827] total reward = 50.364452, length = 1196
# [Episode  828] total reward = -119.615669, length = 73
# [Episode  829] total reward = 70.205780, length = 1473
# [Episode  830] total reward = 68.450874, length = 1490
# [Episode  831] total reward = -109.541527, length = 57
# [Episode  832] total reward = -115.183311, length = 73
# [Episode  833] total reward = -107.672577, length = 72
# [Episode  834] total reward = -98.897133, length = 115
# [Episode  835] total reward = -107.488205, length = 46
# [Episode  836] total reward = 192.469238, length = 1600
# [Episode  837] total reward = -117.469276, length = 64
# [Episode  838] total reward = 179.379608, length = 1600
# [Episode  839] total reward = -117.340714, length = 65
# ...
# [Episode 4718] total reward = -15.767281, length = 541
# [Episode 4719] total reward = 252.226624, length = 1066
# [Episode 4720] total reward = -98.069847, length = 336
# [Episode 4721] total reward = 244.889526, length = 1139
# [Episode 4722] total reward = -125.541405, length = 50
# [Episode 4723] total reward = -109.038986, length = 50
# [Episode 4724] total reward = 246.242523, length = 1145
# [Episode 4725] total reward = 247.043381, length = 1131
# [Episode 4726] total reward = 128.954498, length = 1175
# [Episode 4727] total reward = 247.468628, length = 1124
# [Episode 4728] total reward = -26.836683, length = 430
# [Episode 4729] total reward = 51.898010, length = 785
# [Episode 4730] total reward = 252.282913, length = 1080
# [Episode 4731] total reward = 243.766754, length = 1160
# [Episode 4732] total reward = 247.731400, length = 1110
# [Episode 4733] total reward = 252.019775, length = 1067
# [Episode 4734] total reward = 240.307022, length = 1195
# [Episode 4735] total reward = -115.860115, length = 113
# [Episode 4736] total reward = 246.320190, length = 1122
# [Episode 4737] total reward = 244.924316, length = 1146
# [Episode 4738] total reward = 240.115112, length = 1194
# [Episode 4739] total reward = 232.186646, length = 1268
# [Episode 4740] total reward = -127.732529, length = 117
# [Episode 4741] total reward = 250.430725, length = 1087
# [Episode 4742] total reward = 239.161133, length = 1191
# [Episode 4743] total reward = 39.701725, length = 787
# [Episode 4744] total reward = 66.430542, length = 697
# [Episode 4745] total reward = -71.426323, length = 232
# [Episode 4746] total reward = -78.631348, length = 288
# [Episode 4747] total reward = 244.142426, length = 1124
# [Episode 4748] total reward = 98.092728, length = 886
# [Episode 4749] total reward = 249.540268, length = 1100
# [Episode 4750] total reward = 245.224701, length = 1144
# [Episode 4751] total reward = 244.834259, length = 1155
# [Episode 4752] total reward = -113.999718, length = 51
# [Episode 4753] total reward = 246.444473, length = 1119
# [Episode 4754] total reward = 232.515213, length = 1252
# [Episode 4755] total reward = 244.520874, length = 1129
# [Episode 4756] total reward = -72.503555, length = 234
# [Episode 4757] total reward = 245.033524, length = 1130
# [Episode 4758] total reward = -116.115448, length = 74
# [Episode 4759] total reward = 250.771835, length = 1066
# [Episode 4760] total reward = 238.371826, length = 1204
# [Episode 4761] total reward = -82.806808, length = 275
# [Episode 4762] total reward = 245.395859, length = 1131
# [Episode 4763] total reward = 249.866318, length = 1082
# [Episode 4764] total reward = -112.579765, length = 42
# [Episode 4765] total reward = 246.752686, length = 1125
# [Episode 4766] total reward = 243.477783, length = 1152
# [Episode 4767] total reward = -75.732124, length = 218
# [Episode 4768] total reward = 244.833679, length = 1142
# [Episode 4769] total reward = 232.809937, length = 1217
# [Episode 4770] total reward = 243.954132, length = 1126
# [Episode 4771] total reward = 248.509583, length = 1101
# [Episode 4772] total reward = -108.893547, length = 43
# [Episode 4773] total reward = 252.387512, length = 1062
# [Episode 4774] total reward = 244.806168, length = 1129
# [Episode 4775] total reward = 246.498276, length = 1117
# [Episode 4776] total reward = 244.097870, length = 1131
# [Episode 4777] total reward = -110.918701, length = 59
# [Episode 4778] total reward = 240.804245, length = 1180
# [Episode 4779] total reward = 75.470825, length = 869
# [Episode 4780] total reward = 241.497894, length = 1185
# [Episode 4781] total reward = 249.773407, length = 1067
# [Episode 4782] total reward = 250.659378, length = 1093
# [Episode 4783] total reward = 246.742752, length = 1096
# [Episode 4784] total reward = 109.417763, length = 926
# [Episode 4785] total reward = 238.866882, length = 1201
# [Episode 4786] total reward = 239.280441, length = 1184
# [Episode 4787] total reward = 249.516052, length = 1079
# [Episode 4788] total reward = -87.145790, length = 297
# [Episode 4789] total reward = 253.443970, length = 1067
# [Episode 4790] total reward = 242.644943, length = 1180
# [Episode 4791] total reward = 6.995831, length = 886
# [Episode 4792] total reward = 236.053284, length = 1229
# [Episode 4793] total reward = 248.123840, length = 1107
# [Episode 4794] total reward = 248.590958, length = 1107
# [Episode 4795] total reward = 76.532501, length = 847
# [Episode 4796] total reward = 248.663391, length = 1107
# [Episode 4797] total reward = 20.302032, length = 693
# [Episode 4798] total reward = 250.186996, length = 1094
# [Episode 4799] total reward = 254.381485, length = 1040
# [Episode 4800] total reward = 250.704559, length = 1085
#
# [ 4800 /  5000]
# ----------------------------------
# actor loss = -0.094182
# critic loss = 2627.717041
# entropy = 7.801080
# mean return = 134.198253
# mean length = 879.44
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 65.098125, length = 688
# 100%|██████████| 690/690 [00:02<00:00, 253.91it/s]
# [Episode 4801] total reward = 249.623474, length = 1085
# [Episode 4802] total reward = 253.588013, length = 1068
# [Episode 4803] total reward = 241.963821, length = 1161
# [Episode 4804] total reward = 253.905334, length = 1040
# [Episode 4805] total reward = -112.867630, length = 43
# [Episode 4806] total reward = -19.134758, length = 673
# [Episode 4807] total reward = 246.387024, length = 1138
# [Episode 4808] total reward = -109.802513, length = 57
# [Episode 4809] total reward = 244.366425, length = 1158
# [Episode 4810] total reward = 243.761200, length = 1132
# [Episode 4811] total reward = 249.348709, length = 1092
# [Episode 4812] total reward = 247.852509, length = 1111
# [Episode 4813] total reward = 246.663574, length = 1121
# [Episode 4814] total reward = 250.244934, length = 1102
# [Episode 4815] total reward = 240.546204, length = 1193
# [Episode 4816] total reward = 248.437668, length = 1115
# [Episode 4817] total reward = 246.647110, length = 1141
# [Episode 4818] total reward = 255.978745, length = 1027
# [Episode 4819] total reward = 46.116428, length = 637
# [Episode 4820] total reward = -110.547394, length = 52
# [Episode 4821] total reward = 252.668503, length = 1066
# [Episode 4822] total reward = 248.027313, length = 1126
# [Episode 4823] total reward = 253.677338, length = 1047
# [Episode 4824] total reward = 258.652405, length = 992
# [Episode 4825] total reward = 120.972794, length = 1047
# [Episode 4826] total reward = 246.648407, length = 1132
# [Episode 4827] total reward = 248.519318, length = 1092
# [Episode 4828] total reward = 255.251282, length = 1042
# [Episode 4829] total reward = 255.263367, length = 1031
# [Episode 4830] total reward = 254.522095, length = 1026
# [Episode 4831] total reward = 246.643860, length = 1115
# [Episode 4832] total reward = -118.063667, length = 98
# [Episode 4833] total reward = 257.210968, length = 1018
# [Episode 4834] total reward = -125.935623, length = 51
# [Episode 4835] total reward = 252.277908, length = 1066
# [Episode 4836] total reward = -10.958893, length = 494
# [Episode 4837] total reward = 249.667297, length = 1099
# [Episode 4838] total reward = 253.104858, length = 1047
# [Episode 4839] total reward = 256.193787, length = 1022
# [Episode 4840] total reward = 252.227417, length = 1067
# [Episode 4841] total reward = -116.862221, length = 44
# [Episode 4842] total reward = 258.891602, length = 997
# [Episode 4843] total reward = 248.852234, length = 1087
# [Episode 4844] total reward = 252.572296, length = 1037
# [Episode 4845] total reward = 252.189880, length = 1065
# [Episode 4846] total reward = 247.897583, length = 1115
# [Episode 4847] total reward = 254.263718, length = 1043
# [Episode 4848] total reward = 256.129791, length = 1021
# [Episode 4849] total reward = 246.658798, length = 1109
# [Episode 4850] total reward = 240.693298, length = 1184
# [Episode 4851] total reward = 129.729248, length = 1037
# [Episode 4852] total reward = -111.294853, length = 37
# [Episode 4853] total reward = 247.941452, length = 1098
# [Episode 4854] total reward = 248.204376, length = 1102
# [Episode 4855] total reward = 250.651764, length = 1090
# [Episode 4856] total reward = 257.085754, length = 1018
# [Episode 4857] total reward = 246.193085, length = 1123
# [Episode 4858] total reward = 246.898834, length = 1115
# [Episode 4859] total reward = 255.519775, length = 1027
# [Episode 4860] total reward = 131.772766, length = 1011
# [Episode 4861] total reward = -109.820045, length = 34
# [Episode 4862] total reward = 251.068634, length = 1064
# [Episode 4863] total reward = 251.264877, length = 1042
# [Episode 4864] total reward = 254.548157, length = 1023
# [Episode 4865] total reward = 233.857483, length = 1244
# [Episode 4866] total reward = 253.110947, length = 1051
# [Episode 4867] total reward = 250.493210, length = 1073
# [Episode 4868] total reward = 247.984497, length = 1089
# [Episode 4869] total reward = 258.930603, length = 982
# [Episode 4870] total reward = 248.970306, length = 1085
# [Episode 4871] total reward = 252.261642, length = 1063
# [Episode 4872] total reward = 123.250458, length = 946
# [Episode 4873] total reward = 142.014771, length = 959
# [Episode 4874] total reward = 251.052505, length = 1067
# [Episode 4875] total reward = -110.935127, length = 43
# [Episode 4876] total reward = 254.614227, length = 1037
# [Episode 4877] total reward = 256.191376, length = 1004
# [Episode 4878] total reward = 252.237503, length = 1049
# [Episode 4879] total reward = 256.102539, length = 1031
# [Episode 4880] total reward = 257.549683, length = 989
# [Episode 4881] total reward = 256.751892, length = 1001
# [Episode 4882] total reward = -56.871422, length = 283
# [Episode 4883] total reward = -16.137882, length = 522
# [Episode 4884] total reward = 246.371582, length = 1113
# [Episode 4885] total reward = 255.165482, length = 1019
# [Episode 4886] total reward = 253.755096, length = 1025
# [Episode 4887] total reward = 250.378006, length = 1072
# [Episode 4888] total reward = -51.972477, length = 258
# [Episode 4889] total reward = 248.626312, length = 1109
# [Episode 4890] total reward = 255.090942, length = 1036
# [Episode 4891] total reward = 245.434784, length = 1119
# [Episode 4892] total reward = 256.644867, length = 1006
# [Episode 4893] total reward = 249.665710, length = 1076
# [Episode 4894] total reward = -110.699898, length = 33
# [Episode 4895] total reward = 253.650955, length = 1043
# [Episode 4896] total reward = 256.324463, length = 1020
# [Episode 4897] total reward = -7.518452, length = 413
# [Episode 4898] total reward = 257.459900, length = 1013
# [Episode 4899] total reward = 67.013870, length = 736
# [Episode 4900] total reward = 255.238525, length = 1036
# [Episode 4901] total reward = 255.006683, length = 1025
# [Episode 4902] total reward = -69.775047, length = 287
# [Episode 4903] total reward = 100.865089, length = 881
# [Episode 4904] total reward = 241.802109, length = 1171
# [Episode 4905] total reward = 92.435356, length = 947
# [Episode 4906] total reward = 248.154633, length = 1095
# [Episode 4907] total reward = 248.223511, length = 1104
# [Episode 4908] total reward = 245.509659, length = 1124
# [Episode 4909] total reward = 68.557755, length = 855
# [Episode 4910] total reward = 242.727478, length = 1152
# [Episode 4911] total reward = 252.543976, length = 1064
# [Episode 4912] total reward = 246.973083, length = 1110
# [Episode 4913] total reward = 254.616180, length = 1028
# [Episode 4914] total reward = 253.998459, length = 1058
# [Episode 4915] total reward = 254.796417, length = 1052
# [Episode 4916] total reward = 254.855804, length = 1033
# [Episode 4917] total reward = -66.094986, length = 383
# [Episode 4918] total reward = 249.410065, length = 1086
# [Episode 4919] total reward = 251.327164, length = 1093
# [Episode 4920] total reward = 254.167603, length = 1046
# [Episode 4921] total reward = 252.927628, length = 1062
# [Episode 4922] total reward = 256.416199, length = 1019
# [Episode 4923] total reward = 251.669449, length = 1080
# [Episode 4924] total reward = 244.009659, length = 1130
# [Episode 4925] total reward = 249.408508, length = 1095
# [Episode 4926] total reward = 253.549225, length = 1020
# [Episode 4927] total reward = 251.646317, length = 1078
# [Episode 4928] total reward = 248.409760, length = 1085
# [Episode 4929] total reward = -113.198883, length = 70
# [Episode 4930] total reward = -110.577423, length = 52
# [Episode 4931] total reward = 250.031067, length = 1071
# [Episode 4932] total reward = -39.342621, length = 405
# [Episode 4933] total reward = -113.669891, length = 62
# [Episode 4934] total reward = 246.523376, length = 1114
# [Episode 4935] total reward = 253.384628, length = 1041
# [Episode 4936] total reward = 256.332581, length = 1023
# [Episode 4937] total reward = 243.874603, length = 1144
# [Episode 4938] total reward = -79.869675, length = 252
# [Episode 4939] total reward = 251.753586, length = 1061
# [Episode 4940] total reward = 255.518951, length = 1026
# [Episode 4941] total reward = 256.825317, length = 1014
# [Episode 4942] total reward = 248.016968, length = 1086
# [Episode 4943] total reward = 249.843689, length = 1080
# [Episode 4944] total reward = 257.070526, length = 1003
# [Episode 4945] total reward = 19.392082, length = 573
# [Episode 4946] total reward = 247.506378, length = 1079
# [Episode 4947] total reward = 257.037323, length = 1017
# [Episode 4948] total reward = 255.736557, length = 987
# [Episode 4949] total reward = 255.730316, length = 1023
# [Episode 4950] total reward = 256.948608, length = 994
# [Episode 4951] total reward = 253.241638, length = 1047
# [Episode 4952] total reward = 251.616028, length = 1036
# [Episode 4953] total reward = 251.957047, length = 1070
# [Episode 4954] total reward = -109.924301, length = 117
# [Episode 4955] total reward = 10.255775, length = 505
# [Episode 4956] total reward = 258.763580, length = 987
# [Episode 4957] total reward = 123.481628, length = 928
# [Episode 4958] total reward = 258.391174, length = 1000
# [Episode 4959] total reward = 252.878632, length = 1050
# [Episode 4960] total reward = 244.530792, length = 1101
# [Episode 4961] total reward = 255.240723, length = 1030
# [Episode 4962] total reward = 254.925140, length = 1037
# [Episode 4963] total reward = 257.675995, length = 1008
# [Episode 4964] total reward = 258.493103, length = 995
# [Episode 4965] total reward = 259.024841, length = 993
# [Episode 4966] total reward = 252.250381, length = 1042
# [Episode 4967] total reward = -106.505486, length = 175
# [Episode 4968] total reward = 250.244934, length = 1087
# [Episode 4969] total reward = 250.181442, length = 1071
# [Episode 4970] total reward = 90.101097, length = 866
# [Episode 4971] total reward = -116.180222, length = 64
# [Episode 4972] total reward = 257.995728, length = 989
# [Episode 4973] total reward = -13.740635, length = 382
# [Episode 4974] total reward = 256.201843, length = 1012
# [Episode 4975] total reward = 257.641602, length = 984
# [Episode 4976] total reward = 255.183624, length = 1031
# [Episode 4977] total reward = 257.150879, length = 992
# [Episode 4978] total reward = 259.735229, length = 966
# [Episode 4979] total reward = 257.597290, length = 993
# [Episode 4980] total reward = 257.591522, length = 993
# [Episode 4981] total reward = 259.577942, length = 980
# [Episode 4982] total reward = 254.775543, length = 1015
# [Episode 4983] total reward = 255.435883, length = 1003
# [Episode 4984] total reward = 251.108490, length = 1054
# [Episode 4985] total reward = 250.751953, length = 1054
# [Episode 4986] total reward = 247.298996, length = 1099
# [Episode 4987] total reward = 42.235451, length = 722
# [Episode 4988] total reward = 253.381210, length = 1043
# [Episode 4989] total reward = 240.302002, length = 1168
# [Episode 4990] total reward = 256.205353, length = 1015
# [Episode 4991] total reward = 121.689095, length = 941
# [Episode 4992] total reward = 252.014740, length = 1055
# [Episode 4993] total reward = 255.781693, length = 1011
# [Episode 4994] total reward = -111.976067, length = 39
# [Episode 4995] total reward = 10.452850, length = 565
# [Episode 4996] total reward = -126.918976, length = 56
# [Episode 4997] total reward = 255.284088, length = 1043
# [Episode 4998] total reward = 262.445862, length = 951
# [Episode 4999] total reward = 46.898102, length = 692

# %% [markdown]
# ### 5.3 Load the Model and Play

# %%
save_dir = project_root + '/save'
model_path = os.path.join(save_dir, "model.pt")

if os.path.exists(model_path):
    print("Loading the model ... ", end="")
    checkpoint = torch.load(model_path)
    policy_net.load_state_dict(checkpoint["PolicyNet"])
    print("Done.")
else:
    print('ERROR: No model saved')

play(policy_net)
# Out:
# Loading the model ... Done.
# [Evaluation] Total reward = 263.157728, length = 952
# 100%|██████████| 954/954 [00:03<00:00, 265.67it/s]
